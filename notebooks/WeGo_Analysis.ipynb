# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## WeGo Public Transit README

# %% [markdown]
# [WeGo Public Transit](https://www.wegotransit.com/) is a public transit system serving the Greater Nashville and Davidson County area. WeGo provides local and regional bus routes, the WeGo Star train service connecting Lebanon to downtown Nashville, along with several other transit services.
#
# The data for this project can be downloaded from [here](https://drive.google.com/drive/folders/1L8d3xEaPD13BMz_k-3G8XRRLvPIbNRq9?usp=sharing).
#
# Since 2019, WeGo has been using [**Transit Signal Priority (TSP)**](https://www.wegotransit.com/projects/transit-signal-priority/), a technology that helps to manage traffic flow more efficiently. For buses it reduces wait times at traffic signals by holding green lights longer, shortening red lights or in some cases allowing buses to bypass traffic.
#
# The data that you have been provided was collected for trips on Route 50, Charlotte Pike. TSP has been used on portions of this route, with different periods of being on or off, either conditionally or unconditionally. For these timespans, TSP was used between White Bridge and MCC, including all intervening timepoints, in both directions.
# The important dates are as follows:
#
# * February 3rd @ 12 noon: TSP Turned On (Unconditional)
#
# * February 10th @ 12 noon: TSP Schedule-Conditional Priority Begins (Only buses more than 2 minutes late receive priority)
#
# * April 28th @ 12 noon: TSP Turned Off
#
# * May 5th @ 12 noon: TSP Turned On (Unconditional)
#
# * May 12th @ 12 noon: TSP Headway-Conditional TSP Priority Begins (Only gapped buses with actual leading headway more than 120% of scheduled headway receive priority)
#
#
# The first main variable you will be studying in this project is **adherence**, which compares the actual departure time to the scheduled time and is included in the ADHERENCE column. A negative adherence value means that a bus left a time point late and a positive adherence indicates that the bus left the time point early. Buses with adherence values beyond negative 6 are generally considered late and beyond positive 1 are considered early. However, there is some additional logic where the staff applies waivers to allow early departures. For example, express buses that have already picked up everyone at a park-and-ride lot and are only dropping off passengers may be allowed to leave early.  Early departures are also permitted at the end of a trip (when TRIP_EDGE = 2), since they do not affect upstream passengers. **Note:** When determining whether a bus is early or late, it is advised that you use the 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT', and 'ADJUSTED_ONTIME_COUNT' columns in order to account for the adjustments.
#
# The second main variable you'll be looking at is **headway**.  This is the amount of time between a bus and the prior bus at the same stop. In the dataset, the amount of headway scheduled is contained in the SCHEDULED_HDWY column and indicates the difference between the scheduled time for a particular stop and the scheduled time for the previous bus on that same stop.
# This dataset contains a column HDWY_DEV, which shows the amount of deviation from the scheduled headway. **Bunching** occurs when there is shorter headway than scheduled, which would appear as a negative HDWY_DEV value. **Gapping** is when there is more headway than scheduled and appears as a positive value in the HDWY_DEV column. Note that you can calculate headway deviation percentage as HDWY_DEV/SCHEDULED_HDWY. The generally accepted range of headway deviation is 50% to 150% of the scheduled headway, so if scheduled headway is 10 minutes, a headway deviation of up to 5 minutes would be acceptable (but not ideal).
#
# How has TSP affected these two metrics? Keep in mind that there are many other factors that could also be contributing, so be sure to take into account things like day of the week, time of day, time of year (school in session or not), or other factors that may also be affecting adherence or headway deviation.

# %% [markdown]
# ## Exploring

# %%
# Retrieve Data
wego = pd.read_csv("../data/Route 50 Timepoint and Headway Data, 1-1-2023 through 5-12-2025.csv")

# %%
# Look at Columns
wego.columns
# Out:
# Index(['CALENDAR_ID', 'SERVICE_ABBR', 'ADHERENCE_ID', 'DATE', 'ROUTE_ABBR',
#        'BLOCK_ABBR', 'OPERATOR', 'TRIP_ID', 'OVERLOAD_ID',
#        'ROUTE_DIRECTION_NAME', 'TIME_POINT_ABBR', 'ROUTE_STOP_SEQUENCE',
#        'TRIP_EDGE', 'LATITUDE', 'LONGITUDE', 'SCHEDULED_TIME',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE',
#        'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
#        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'BLOCK_STOP_ORDER',
#        'DWELL_IN_MINS'],
#       dtype='object')

# %%
# CALENDAR time Columns
wego[['CALENDAR_ID', 'SERVICE_ABBR', 'DATE']]

# CalendarID: 1{year}{mm}{dd}
# Service Abbr: 1 = Weekday, 2 = Saturday, 3 = Sunday
# Date: presumably datetime timestamp format
# Out:
#         CALENDAR_ID  SERVICE_ABBR        DATE
# 0         120230101             3  2023-01-01
# 1         120230101             3  2023-01-01
# 2         120230101             3  2023-01-01
# 3         120230101             3  2023-01-01
# 4         120230101             3  2023-01-01
# ...             ...           ...         ...
# 618993    120250512             1  2025-05-12
# 618994    120250512             1  2025-05-12
# 618995    120250512             1  2025-05-12
# 618996    120250512             1  2025-05-12
# 618997    120250512             1  2025-05-12
#
# [618998 rows x 3 columns]

# %%
# Route Identification Columns
wego[['ROUTE_ABBR', 'OPERATOR', 'TRIP_ID', 'ROUTE_DIRECTION_NAME', 'TRIP_EDGE', 'IS_RELIEF']]

# todo
# REMOVE route_abbr
# Scrutinize route_direction_name
# Possibly use is_relief to filter for normal trips
# Out:
#         ROUTE_ABBR  OPERATOR  TRIP_ID ROUTE_DIRECTION_NAME  TRIP_EDGE  \
# 0               50      2355   332422          TO DOWNTOWN          1
# 1               50      2355   332422          TO DOWNTOWN          0
# 2               50      2355   332422          TO DOWNTOWN          0
# 3               50      2355   332422          TO DOWNTOWN          0
# 4               50      2355   332422          TO DOWNTOWN          0
# ...            ...       ...      ...                  ...        ...
# 618993          50      3077   432121        FROM DOWNTOWN          2
# 618994          50      3246   432353          TO DOWNTOWN          1
# 618995          50      3246   432353          TO DOWNTOWN          2
# 618996          50      2448   432387          TO DOWNTOWN          1
# 618997          50      2448   432387          TO DOWNTOWN          2
#
#         IS_RELIEF
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 618993          0
# 618994          0
# 618995          0
# 618996          0
# 618997          0
#
# [618998 rows x 6 columns]

# %%
# Efficiency Metrics
wego[['ADHERENCE_ID', 'TIME_POINT_ABBR', 'SCHEDULED_TIME', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE', 'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'DWELL_IN_MINS']]

#lOTS of stuff here.. but I think all I need is:
# [['TIME_POINT_ABBR', 'ADHERENCE', 'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT']]

# The data dictionary describes the adherence_id as a unique identifier for each record but... I don't think that means anything to me as an analyst.
# If it has no relation to the other records than it has no insightful value.

# The 'time' columns that show the actual times that the buses moved are overshadowed by the adherence and headway columns I believe.
# There are also the on time flag columns that tell me if the bus is considered ontime, so any information I can get from these columns I already have.

# I am not so sure about dwell in mins. I think that the columns I'm keeping provide more insightful value than dwell times.

# REMOVE adherence_id column, scheduled/actual time columns,
# Out:
#         ADHERENCE_ID TIME_POINT_ABBR SCHEDULED_TIME ACTUAL_ARRIVAL_TIME  \
# 0           93549161            WALM       05:34:00            05:29:52
# 1           93549162            HLWD       05:40:00            05:42:38
# 2           93549163            WHBG       05:47:00            05:48:29
# 3           93549164            CH46       05:50:00            05:50:34
# 4           93549165        28&CHARL       05:54:00            05:53:14
# ...              ...             ...            ...                 ...
# 618993     119531049            HEAD       07:40:00            07:33:12
# 618994     119531638            HEAD       15:05:00            14:38:33
# 618995     119531639         MCC4_20       15:18:00            15:18:06
# 618996     119531770            MLKS       15:20:00            15:14:10
# 618997     119531771         MCC5_11       15:37:00            15:29:16
#
#        ACTUAL_DEPARTURE_TIME  ADHERENCE  SCHEDULED_HDWY  ACTUAL_HDWY  \
# 0                   05:38:00  -4.000000             NaN          NaN
# 1                   05:42:38  -2.633333             NaN          NaN
# 2                   05:48:29  -1.483333             NaN          NaN
# 3                   05:50:34  -0.566666             NaN          NaN
# 4                   05:55:23  -1.383333             NaN          NaN
# ...                      ...        ...             ...          ...
# 618993              07:37:42   2.300000             NaN          NaN
# 618994              15:05:50  -0.833333             NaN          NaN
# 618995              15:18:14  -0.233333             NaN          NaN
# 618996              15:22:20  -2.333333            10.0    10.883333
# 618997              15:31:28   5.533333             NaN          NaN
#
#         HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# 0            NaN                     0                    0
# 1            NaN                     0                    0
# 2            NaN                     0                    0
# 3            NaN                     0                    0
# 4            NaN                     0                    0
# ...          ...                   ...                  ...
# 618993       NaN                     1                    0
# 618994       NaN                     0                    0
# 618995       NaN                     0                    0
# 618996  0.883333                     0                    0
# 618997       NaN                     0                    0
#
#         ADJUSTED_ONTIME_COUNT  DWELL_IN_MINS
# 0                           1       8.133333
# 1                           1       0.000000
# 2                           1       0.000000
# 3                           1       0.000000
# 4                           1       2.150000
# ...                       ...            ...
# 618993                      0       4.500000
# 618994                      1      27.283333
# 618995                      1       0.133333
# 618996                      1       8.166666
# 618997                      1       2.200000
#
# [618998 rows x 13 columns]

# %%
# Other Dimensions / Facts
wego[['BLOCK_ABBR', 'OVERLOAD_ID', 'ROUTE_STOP_SEQUENCE', 'LATITUDE', 'LONGITUDE', 'STOP_CANCELLED', 'PREV_SCHED_STOP_CANCELLED', 'BLOCK_STOP_ORDER']]

# The BLOCK_ABBR shows me what section of the route a stop is on... I don't think that's useful. Details are better?
# The ROUTE_STOP_SEQUENCE identifies the stop point... I don't think that's useful.
# In the data dictionary BLOCK_STOP_ORDER is blank. I'll ask about it but seems like she goes.

# The OVERLOAD_ID can show me routes that are abnormal to exclude.
# LATITUDE and LONGITUDE will be useful for geospatial possibilities.
# STOP_CANCELLED and PREV_SCHED_STOP_CANCELLED could help me exclude abnormal circumstances.
# For PREV_SCHED_STOP_CANCELLED: Useful for excluding records where the headway values are extremely high because the bus is just coming off a detour.
# Out:
#         BLOCK_ABBR  OVERLOAD_ID  ROUTE_STOP_SEQUENCE   LATITUDE  LONGITUDE  \
# 0             5000            0                   17  36.132451 -86.907214
# 1             5000            0                   16  36.138535 -86.881130
# 2             5000            0                   15  36.149997 -86.858261
# 3             5000            0                   14  36.152077 -86.842746
# 4             5000            0                   13  36.153870 -86.818414
# ...            ...          ...                  ...        ...        ...
# 618993        8401            0                   12  36.158659 -86.804683
# 618994        9302            0                    7  36.158659 -86.804683
# 618995        9302            0                    4  36.167091 -86.781923
# 618996        9950            0                   11  36.161197 -86.800180
# 618997        9950            0                    5  36.167091 -86.781923
#
#         STOP_CANCELLED  PREV_SCHED_STOP_CANCELLED  BLOCK_STOP_ORDER
# 0                    0                        0.0                 2
# 1                    0                        0.0                 5
# 2                    0                        0.0                11
# 3                    0                        0.0                13
# 4                    0                        0.0                18
# ...                ...                        ...               ...
# 618993               0                        NaN                23
# 618994               0                        0.0                 2
# 618995               0                        NaN                 3
# 618996               0                        0.0                 2
# 618997               0                        NaN                 3
#
# [618998 rows x 8 columns]

# %%
# Lets take a closer look at the columns I'm unsure of:
# ROUTE_DIRECTION_NAME: TO_DOWNTOWN
(
    wego
    .loc[wego['ROUTE_DIRECTION_NAME'] == 'TO DOWNTOWN']
    .loc[wego['CALENDAR_ID'] == 120230101]
    .loc[wego['TRIP_ID'] == 332482]
    [[
        'CALENDAR_ID', 'SERVICE_ABBR', 'DATE',
        'OPERATOR', 'TRIP_ID', 'ROUTE_DIRECTION_NAME', 
        'TIME_POINT_ABBR', 'TRIP_EDGE', 'SCHEDULED_TIME',
        'ADHERENCE', 'SCHEDULED_HDWY', 'ACTUAL_HDWY', 
        'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT'
     ]]
)
# Out:
#      CALENDAR_ID  SERVICE_ABBR        DATE  OPERATOR  TRIP_ID  \
# 144    120230101             3  2023-01-01      2217   332482
# 145    120230101             3  2023-01-01      2217   332482
# 146    120230101             3  2023-01-01      2217   332482
# 147    120230101             3  2023-01-01      2217   332482
# 148    120230101             3  2023-01-01      2217   332482
# 149    120230101             3  2023-01-01      2217   332482
#
#     ROUTE_DIRECTION_NAME TIME_POINT_ABBR  TRIP_EDGE SCHEDULED_TIME  ADHERENCE  \
# 144          TO DOWNTOWN            WALM          1       06:03:00  -0.983333
# 145          TO DOWNTOWN            HLWD          0       06:09:00   0.600000
# 146          TO DOWNTOWN            WHBG          0       06:17:00   0.983333
# 147          TO DOWNTOWN            CH46          0       06:20:00   0.816666
# 148          TO DOWNTOWN        28&CHARL          0       06:24:00   0.866666
# 149          TO DOWNTOWN          MCC5_1          2       06:35:00   6.366666
#
#      SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  \
# 144            29.0    25.983333 -3.016667                     0
# 145            29.0    25.766666 -3.233334                     0
# 146            30.0    27.533333 -2.466667                     0
# 147            30.0    28.616666 -1.383334                     0
# 148            30.0    27.750000 -2.250000                     0
# 149             NaN          NaN       NaN                     0
#
#      ADJUSTED_LATE_COUNT  ADJUSTED_ONTIME_COUNT
# 144                    0                      1
# 145                    0                      1
# 146                    0                      1
# 147                    0                      1
# 148                    0                      1
# 149                    0                      1

# %%
# ROUTE_DIRECTION_NAME: FROM_DOWNTOWN
(
    wego
    .loc[wego['ROUTE_DIRECTION_NAME'] == 'FROM DOWNTOWN']
    .loc[wego['CALENDAR_ID'] == 120230101]
    .loc[wego['TRIP_ID'] == 332423]
    [[
        'CALENDAR_ID', 'SERVICE_ABBR', 'DATE',
        'OPERATOR', 'TRIP_ID', 'ROUTE_DIRECTION_NAME', 
        'TIME_POINT_ABBR', 'TRIP_EDGE', 'SCHEDULED_TIME',
        'ADHERENCE', 'SCHEDULED_HDWY', 'ACTUAL_HDWY', 
        'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT'
     ]]
)
# Out:
#     CALENDAR_ID  SERVICE_ABBR        DATE  OPERATOR  TRIP_ID  \
# 6     120230101             3  2023-01-01      2355   332423
# 7     120230101             3  2023-01-01      2355   332423
# 8     120230101             3  2023-01-01      2355   332423
# 9     120230101             3  2023-01-01      2355   332423
# 10    120230101             3  2023-01-01      2355   332423
# 11    120230101             3  2023-01-01      2355   332423
#
#    ROUTE_DIRECTION_NAME TIME_POINT_ABBR  TRIP_EDGE SCHEDULED_TIME  ADHERENCE  \
# 6         FROM DOWNTOWN          MCC5_1          1       06:15:00  -5.200000
# 7         FROM DOWNTOWN        28&CHARL          0       06:25:00  -1.916666
# 8         FROM DOWNTOWN            CH46          0       06:29:00  -2.483333
# 9         FROM DOWNTOWN            WHBG          0       06:33:00  -2.200000
# 10        FROM DOWNTOWN            HLWD          0       06:40:00  -0.683333
# 11        FROM DOWNTOWN            WALM          2       06:47:00   2.983333
#
#     SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  \
# 6              NaN          NaN       NaN                     0
# 7              NaN          NaN       NaN                     0
# 8              NaN          NaN       NaN                     0
# 9              NaN          NaN       NaN                     0
# 10             NaN          NaN       NaN                     0
# 11             NaN          NaN       NaN                     0
#
#     ADJUSTED_LATE_COUNT  ADJUSTED_ONTIME_COUNT
# 6                     0                      1
# 7                     0                      1
# 8                     0                      1
# 9                     0                      1
# 10                    0                      1
# 11                    0                      1

# %%
# I know that there are TSP systems only from Charlotte up to Whitebridge Rd, 
# so this ROUTE_DIRECTION_NAME column could be useful for determining that
# I don't think I will know until I get to the meat of it.

# %%
# DWELL_IN_MINS
wego['DWELL_IN_MINS'].sort_values(ascending=False).head()

# This doesn't look right... but I'm unsure if I can rule this out yet.
# I believe ADHERENCE and HDWY columns are solely what's necessary to determine efficiency, but this may come in to play.
# Either way it needs some cleaning. Scientific numbers are never a good sign.
# Out:
# 346870    2.132813e+06
# 352298    1.124500e+03
# 530746    5.762667e+02
# 308935    4.187667e+02
# 434647    3.795000e+02
# Name: DWELL_IN_MINS, dtype: float64

# %%
# I'm curious about the connection between TRIP_ID and ROUTE_DIRECTION_NAME
wego[['TRIP_ID', 'ROUTE_DIRECTION_NAME']].groupby(['TRIP_ID', 'ROUTE_DIRECTION_NAME']).size().reset_index().rename(columns={0:'count'})
# Out:
#       TRIP_ID ROUTE_DIRECTION_NAME  count
# 0      332380          TO DOWNTOWN     65
# 1      332381        FROM DOWNTOWN     60
# 2      332382          TO DOWNTOWN     60
# 3      332383        FROM DOWNTOWN     60
# 4      332384          TO DOWNTOWN     60
# ...       ...                  ...    ...
# 5720   429701          TO DOWNTOWN     58
# 5721   430504        FROM DOWNTOWN     56
# 5722   432121        FROM DOWNTOWN     58
# 5723   432353          TO DOWNTOWN     60
# 5724   432387          TO DOWNTOWN     59
#
# [5725 rows x 3 columns]

# %% [markdown]
# I like this but I don't think it does anything for me really.
# Might be useful for double checking things or looking at specific trips.

# %% [markdown]
# ## Cleaning

# %%
wego.columns
# Out:
# Index(['CALENDAR_ID', 'SERVICE_ABBR', 'ADHERENCE_ID', 'DATE', 'ROUTE_ABBR',
#        'BLOCK_ABBR', 'OPERATOR', 'TRIP_ID', 'OVERLOAD_ID',
#        'ROUTE_DIRECTION_NAME', 'TIME_POINT_ABBR', 'ROUTE_STOP_SEQUENCE',
#        'TRIP_EDGE', 'LATITUDE', 'LONGITUDE', 'SCHEDULED_TIME',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE',
#        'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
#        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'BLOCK_STOP_ORDER',
#        'DWELL_IN_MINS'],
#       dtype='object')

# %% [markdown]
# #### Combining Date and Time columns

# %%
wego['ACTUAL_DEPARTURE_TIME']
# Out:
# 0         05:38:00
# 1         05:42:38
# 2         05:48:29
# 3         05:50:34
# 4         05:55:23
#             ...
# 618993    07:37:42
# 618994    15:05:50
# 618995    15:18:14
# 618996    15:22:20
# 618997    15:31:28
# Name: ACTUAL_DEPARTURE_TIME, Length: 618998, dtype: object

# %%
wego['ACTUAL_DEPARTURE_TIME'][1539]
# Out:
# '1900-01-01 00:02:04'

# %%
wego.iloc[1539:1540][['CALENDAR_ID', 'SERVICE_ABBR', 'DATE',
        'OPERATOR', 'TRIP_ID', 'ROUTE_DIRECTION_NAME', 
        'TIME_POINT_ABBR', 'TRIP_EDGE', 'SCHEDULED_TIME', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME',
        'ADHERENCE', 'SCHEDULED_HDWY', 'ACTUAL_HDWY', 
        'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT']]
# Out:
#       CALENDAR_ID  SERVICE_ABBR        DATE  OPERATOR  TRIP_ID  \
# 1539    120230103             1  2023-01-03      1623   332573
#
#      ROUTE_DIRECTION_NAME TIME_POINT_ABBR  TRIP_EDGE       SCHEDULED_TIME  \
# 1539        FROM DOWNTOWN            WHBG          0  1900-01-01 00:01:00
#
#      ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  ADHERENCE  SCHEDULED_HDWY  \
# 1539            23:59:47   1900-01-01 00:02:04  -1.066666            30.0
#
#       ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# 1539    26.766666 -3.233334                     0                    0
#
#       ADJUSTED_ONTIME_COUNT
# 1539                      1

# %%
# Combining Date and Time columns
# wego['comb_timestamp_departure'] = 
pd.to_datetime(wego['DATE'] + ' ' + pd.to_datetime(wego['ACTUAL_DEPARTURE_TIME'], format='%H:%M:%S', exact=False).astype(str))
# Out:
# C:\Users\nunuk\AppData\Local\Temp\ipykernel_9768\527222452.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(wego['DATE'] + ' ' + pd.to_datetime(wego['ACTUAL_DEPARTURE_TIME'], format='%H:%M:%S', exact=False).astype(str))
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[99], line 3
#       1 # Combining Date and Time columns
#       2 # wego['comb_timestamp_departure'] =
# ----> 3 pd.to_datetime(wego['DATE'] + ' ' + pd.to_datetime(wego['ACTUAL_DEPARTURE_TIME'], format='%H:%M:%S', exact=False).astype(str))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     432 if format is not None and format != "mixed":
#     433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#     438     yearfirst=yearfirst,
#     439     utc=utc,
#     440     errors=errors,
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#     447     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2398, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2395 # if str-dtype, convert
#    2396 data = np.asarray(data, dtype=np.object_)
# -> 2398 result, tz_parsed = tslib.array_to_datetime(
#    2399     data,
#    2400     errors=errors,
#    2401     utc=utc,
#    2402     dayfirst=dayfirst,
#    2403     yearfirst=yearfirst,
#    2404     creso=abbrev_to_npy_unit(out_unit),
#    2405 )
#    2407 if tz_parsed is not None:
#    2408     # We can take a shortcut since the datetime64 numpy array
#    2409     #  is in UTC
#    2410     return result, tz_parsed
#
# File tslib.pyx:414, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:553, in pandas._libs.tslib.array_to_datetime()
#
# File conversion.pyx:641, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File parsing.pyx:336, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File parsing.pyx:666, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse: 2023-01-03 NaT, at position 1195

# %%
wego['ACTUAL_DEPARTURE_TIME'] = pd.to_datetime(wego['ACTUAL_DEPARTURE_TIME'], format="%H:%M:%S", exact=False).dt.time

# %%
# REVISION: Andy shared this code he used to narrow it down by date and flag each row based on tsp status.
# EDIT: I had to edit this code to ensure accuracy.
tsp_window = [
    (wego['DATE']>="2025-02-03") & (wego['DATE']<"2025-02-10") & (wego['ACTUAL_DEPARTURE_TIME'].hour> pd.to_datetime('12:00:00', format="%H:%M:%S")) ,
    (wego['DATE']>="2025-02-10") & (wego['DATE']<"2025-04-28") & (wego['ACTUAL_DEPARTURE_TIME'].dt.time>'12:00:00'),
    (wego['DATE']>="2025-04-28") & (wego['DATE']<"2025-05-05") & (wego['ACTUAL_DEPARTURE_TIME'].dt.time>'12:00:00'),
    (wego['DATE']>="2025-05-05") & (wego['DATE']<"2025-05-12") & (wego['ACTUAL_DEPARTURE_TIME'].dt.time>'12:00:00'),
    (wego['DATE']>="2025-05-12") & (wego['ACTUAL_DEPARTURE_TIME'].dt.time>noon.dt.time)
]
phases = [
    "tsp_on_uncond",
    "tsp_on_sched_cond",
    "tsp_off",
    "tsp_on_uncond",
    "tsp_on_hdwy_cond"
]
wego["tsp_status"] = np.select(tsp_window, phases, default="tsp_off")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9768\903622960.py in ?()
#       1 # REVISION: Andy shared this code he used to narrow it down by date and flag each row based on tsp status.
#       2 # EDIT: I had to edit this code to ensure accuracy.
#       3 tsp_window = [
# ----> 4     (wego['DATE']>="2025-02-03") & (wego['DATE']<"2025-02-10") & (wego['ACTUAL_DEPARTURE_TIME'].hour> pd.to_datetime('12:00:00', format="%H:%M:%S")) ,
#       5     (wego['DATE']>="2025-02-10") & (wego['DATE']<"2025-04-28") & (wego['ACTUAL_DEPARTURE_TIME'].dt.time>'12:00:00'),
#       6     (wego['DATE']>="2025-04-28") & (wego['DATE']<"2025-05-05") & (wego['ACTUAL_DEPARTURE_TIME'].dt.time>'12:00:00'),
#       7     (wego['DATE']>="2025-05-05") & (wego['DATE']<"2025-05-12") & (wego['ACTUAL_DEPARTURE_TIME'].dt.time>'12:00:00'),
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'hour'

# %% [markdown]
# #### Trimming

# %%
# Selecting relevant columns to keep
wego_trim = wego[['CALENDAR_ID', 'SERVICE_ABBR', 'DATE',
        'OPERATOR', 'TRIP_ID', 'ROUTE_DIRECTION_NAME', 
        'TIME_POINT_ABBR', 'TRIP_EDGE', 'SCHEDULED_TIME', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME',
        'ADHERENCE', 'SCHEDULED_HDWY', 'ACTUAL_HDWY', 
        'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT',
        'STOP_CANCELLED', 'PREV_SCHED_STOP_CANCELLED', 
        'IS_RELIEF']]

# %%
# Rename Columns
wego_trim = wego_trim.rename(columns={"CALENDAR_ID": "cal_id", 
                            "SERVICE_ABBR": "service_day",
                            "DATE" : "date",
                            "OPERATOR" : "operator_id",
                            "TRIP_ID" : "trip_id",
                            "ROUTE_DIRECTION_NAME" : "route_direction",
                            "TIME_POINT_ABBR" : "time_point",
                            "TRIP_EDGE" : "trip_edge",
                            "SCHEDULED_TIME" : "sched_time",
                            "ADHERENCE" : "adherence",
                            "SCHEDULED_HDWY" : "sched_hdwy",
                            "ACTUAL_HDWY" : "act_hdwy",
                            "HDWY_DEV" : "hdwy_dev",
                            "ADJUSTED_EARLY_COUNT" : "adj_early",
                            "ADJUSTED_LATE_COUNT" : "adj_late",
                            "ADJUSTED_ONTIME_COUNT" : "adj_ontime"})

# %% [markdown]
# ### Combining the ajd_early, adj_late, and adj_ontime columns into one flag column. (Andy's Idea)

# %%
wego_trim.head(1)
# Out:
#       cal_id  service_day        date  operator_id  trip_id route_direction  \
# 0  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
#
#   time_point  trip_edge sched_time ACTUAL_ARRIVAL_TIME  ... adherence  \
# 0       WALM          1   05:34:00            05:29:52  ...      -4.0
#
#    sched_hdwy  act_hdwy  hdwy_dev  adj_early  adj_late  adj_ontime  \
# 0         NaN       NaN       NaN          0         0           1
#
#    STOP_CANCELLED  PREV_SCHED_STOP_CANCELLED  IS_RELIEF
# 0               0                        0.0          0
#
# [1 rows x 21 columns]

# %%
# Writing flag_sort function to sort and debug
row_indexes = []
row_sums = []

def flag_sort(row):
    if (row['adj_early'] + row['adj_late'] + row['adj_ontime']) == 1:
        if row['adj_early'] == 1:
            return 1
        if row['adj_late'] == 1:
            return 2
        if row['adj_ontime'] == 1:
            return 3
    else:
        row_indexes.append(row.name)
        row_sums.append(row['adj_early'] + row['adj_late'] + row['adj_ontime'])
        print('Error at: ' + str(row.name))
        print('      sum adj cols: ' + str(row['adj_early'] + row['adj_late'] + row['adj_ontime']))

# %%
# Testing
wego_trim.iloc[50:60].apply(flag_sort, axis=1)
# Out:
# 50    2
# 51    2
# 52    2
# 53    3
# 54    1
# 55    3
# 56    3
# 57    3
# 58    3
# 59    3
# dtype: int64

# %%
# Checking
wego_trim[['adj_early', 'adj_late', 'adj_ontime']].iloc[50:60]
# Out:
#     adj_early  adj_late  adj_ontime
# 50          0         1           0
# 51          0         1           0
# 52          0         1           0
# 53          0         0           1
# 54          1         0           0
# 55          0         0           1
# 56          0         0           1
# 57          0         0           1
# 58          0         0           1
# 59          0         0           1

# %%
# Blast off
wego_trim['timing_flag'] = wego_trim.apply(flag_sort, axis=1)
# Out:
# Error at: 1195
#       sum adj cols: 0
# Error at: 1196
#       sum adj cols: 0
# Error at: 1207
#       sum adj cols: 0
# Error at: 1208
#       sum adj cols: 0
# Error at: 1209
#       sum adj cols: 0
# Error at: 1210
#       sum adj cols: 0
# Error at: 1211
#       sum adj cols: 0
# Error at: 1212
#       sum adj cols: 0
# Error at: 1213
#       sum adj cols: 0
# Error at: 1214
#       sum adj cols: 0
# Error at: 1220
#       sum adj cols: 0
# Error at: 1291
#       sum adj cols: 0
# Error at: 1292
#       sum adj cols: 0
# Error at: 1293
#       sum adj cols: 0
# Error at: 1294
#       sum adj cols: 0
# Error at: 1295
#       sum adj cols: 0
# Error at: 1296
#       sum adj cols: 0
# Error at: 1297
#       sum adj cols: 0
# Error at: 1298
#       sum adj cols: 0
# Error at: 1299
#       sum adj cols: 0
# Error at: 1300
#       sum adj cols: 0
# Error at: 1809
#       sum adj cols: 0
# Error at: 1810
#       sum adj cols: 0
# Error at: 1811
#       sum adj cols: 0
# Error at: 1812
#       sum adj cols: 0
# Error at: 1914
#       sum adj cols: 0
# Error at: 1915
#       sum adj cols: 0
# Error at: 1916
#       sum adj cols: 0
# Error at: 1917
#       sum adj cols: 0
# Error at: 1918
#       sum adj cols: 0
# Error at: 2114
#       sum adj cols: 0
# Error at: 2115
#       sum adj cols: 0
# Error at: 2116
#       sum adj cols: 0
# Error at: 2117
#       sum adj cols: 0
# Error at: 2118
#       sum adj cols: 0
# Error at: 2119
#       sum adj cols: 0
# Error at: 2120
#       sum adj cols: 0
# Error at: 2121
#       sum adj cols: 0
# Error at: 3612
#       sum adj cols: 0
# Error at: 3648
#       sum adj cols: 0
# Error at: 3668
#       sum adj cols: 0
# Error at: 3692
#       sum adj cols: 0
# Error at: 3704
#       sum adj cols: 0
# Error at: 3705
#       sum adj cols: 0
# Error at: 5142
#       sum adj cols: 0
# Error at: 5143
#       sum adj cols: 0
# Error at: 5144
#       sum adj cols: 0
# Error at: 5145
#       sum adj cols: 0
# Error at: 5146
#       sum adj cols: 0
# Error at: 5147
#       sum adj cols: 0
# Error at: 5148
#       sum adj cols: 0
# Error at: 5149
#       sum adj cols: 0
# Error at: 5150
#       sum adj cols: 0
# Error at: 5151
#       sum adj cols: 0
# Error at: 5152
#       sum adj cols: 0
# Error at: 5153
#       sum adj cols: 0
# Error at: 5154
#       sum adj cols: 0
# Error at: 5155
#       sum adj cols: 0
# Error at: 5156
#       sum adj cols: 0
# Error at: 5157
#       sum adj cols: 0
# Error at: 5158
#       sum adj cols: 0
# Error at: 5159
#       sum adj cols: 0
# Error at: 5160
#       sum adj cols: 0
# Error at: 5161
#       sum adj cols: 0
# Error at: 5162
#       sum adj cols: 0
# Error at: 5163
#       sum adj cols: 0
# Error at: 5164
#       sum adj cols: 0
# Error at: 5165
#       sum adj cols: 0
# Error at: 5166
#       sum adj cols: 0
# Error at: 5167
#       sum adj cols: 0
# Error at: 5168
#       sum adj cols: 0
# Error at: 5169
#       sum adj cols: 0
# Error at: 5170
#       sum adj cols: 0
# Error at: 5171
#       sum adj cols: 0
# Error at: 5172
#       sum adj cols: 0
# Error at: 5173
#       sum adj cols: 0
# Error at: 5174
#       sum adj cols: 0
# Error at: 5175
#       sum adj cols: 0
# Error at: 5176
#       sum adj cols: 0
# Error at: 5177
#       sum adj cols: 0
# Error at: 5178
#       sum adj cols: 0
# Error at: 5179
#       sum adj cols: 0
# Error at: 5180
#       sum adj cols: 0
# Error at: 5181
#       sum adj cols: 0
# Error at: 5182
#       sum adj cols: 0
# Error at: 5959
#       sum adj cols: 0
# Error at: 5961
#       sum adj cols: 0
# Error at: 5962
#       sum adj cols: 0
# Error at: 5965
#       sum adj cols: 0
# Error at: 5966
#       sum adj cols: 0
# Error at: 5967
#       sum adj cols: 0
# Error at: 5968
#       sum adj cols: 0
# Error at: 5969
#       sum adj cols: 0
# Error at: 5970
#       sum adj cols: 0
# Error at: 5971
#       sum adj cols: 0
# Error at: 5972
#       sum adj cols: 0
# Error at: 5973
#       sum adj cols: 0
# Error at: 5974
#       sum adj cols: 0
# Error at: 5975
#       sum adj cols: 0
# Error at: 5976
#       sum adj cols: 0
# Error at: 5977
#       sum adj cols: 0
# Error at: 5978
#       sum adj cols: 0
# Error at: 5979
#       sum adj cols: 0
# Error at: 5980
#       sum adj cols: 0
# Error at: 5981
#       sum adj cols: 0
# Error at: 5982
#       sum adj cols: 0
# Error at: 5983
#       sum adj cols: 0
# Error at: 5984
#       sum adj cols: 0
# Error at: 5985
#       sum adj cols: 0
# Error at: 5986
#       sum adj cols: 0
# Error at: 5987
#       sum adj cols: 0
# Error at: 5988
#       sum adj cols: 0
# Error at: 5989
#       sum adj cols: 0
# Error at: 5990
#       sum adj cols: 0
# Error at: 5991
#       sum adj cols: 0
# Error at: 5992
#       sum adj cols: 0
# Error at: 5993
#       sum adj cols: 0
# Error at: 5994
#       sum adj cols: 0
# Error at: 5995
#       sum adj cols: 0
# Error at: 5996
#       sum adj cols: 0
# Error at: 5997
#       sum adj cols: 0
# Error at: 5998
#       sum adj cols: 0
# Error at: 5999
#       sum adj cols: 0
# Error at: 6000
#       sum adj cols: 0
# Error at: 6001
#       sum adj cols: 0
# Error at: 6002
#       sum adj cols: 0
# Error at: 6003
#       sum adj cols: 0
# Error at: 6004
#       sum adj cols: 0
# Error at: 6005
#       sum adj cols: 0
# Error at: 6006
#       sum adj cols: 0
# Error at: 6007
#       sum adj cols: 0
# Error at: 6008
#       sum adj cols: 0
# Error at: 6009
#       sum adj cols: 0
# Error at: 6010
#       sum adj cols: 0
# Error at: 6011
#       sum adj cols: 0
# Error at: 6012
#       sum adj cols: 0
# Error at: 6013
#       sum adj cols: 0
# Error at: 6014
#       sum adj cols: 0
# Error at: 6015
#       sum adj cols: 0
# Error at: 6016
#       sum adj cols: 0
# Error at: 6017
#       sum adj cols: 0
# Error at: 6018
#       sum adj cols: 0
# Error at: 6019
#       sum adj cols: 0
# Error at: 6020
#       sum adj cols: 0
# Error at: 6021
#       sum adj cols: 0
# Error at: 6022
#       sum adj cols: 0
# Error at: 6023
#       sum adj cols: 0
# Error at: 6024
#       sum adj cols: 0
# Error at: 6025
#       sum adj cols: 0
# Error at: 6026
#       sum adj cols: 0
# Error at: 6027
#       sum adj cols: 0
# Error at: 6028
#       sum adj cols: 0
# Error at: 6029
#       sum adj cols: 0
# Error at: 6030
#       sum adj cols: 0
# Error at: 6031
#       sum adj cols: 0
# Error at: 6032
#       sum adj cols: 0
# Error at: 6033
#       sum adj cols: 0
# Error at: 6034
#       sum adj cols: 0
# Error at: 6035
#       sum adj cols: 0
# Error at: 6036
#       sum adj cols: 0
# Error at: 6037
#       sum adj cols: 0
# Error at: 6038
#       sum adj cols: 0
# Error at: 6039
#       sum adj cols: 0
# Error at: 6040
#       sum adj cols: 0
# Error at: 6041
#       sum adj cols: 0
# Error at: 6042
#       sum adj cols: 0
# Error at: 6043
#       sum adj cols: 0
# Error at: 6044
#       sum adj cols: 0
# Error at: 6045
#       sum adj cols: 0
# Error at: 6046
#       sum adj cols: 0
# Error at: 6047
#       sum adj cols: 0
# Error at: 6048
#       sum adj cols: 0
# Error at: 6049
#       sum adj cols: 0
# Error at: 6050
#       sum adj cols: 0
# Error at: 6051
#       sum adj cols: 0
# Error at: 6052
#       sum adj cols: 0
# Error at: 6053
#       sum adj cols: 0
# Error at: 6054
#       sum adj cols: 0
# Error at: 6055
#       sum adj cols: 0
# Error at: 6056
#       sum adj cols: 0
# Error at: 6057
#       sum adj cols: 0
# Error at: 6058
#       sum adj cols: 0
# Error at: 6059
#       sum adj cols: 0
# Error at: 6060
#       sum adj cols: 0
# Error at: 6061
#       sum adj cols: 0
# Error at: 6062
#       sum adj cols: 0
# Error at: 6063
#       sum adj cols: 0
# Error at: 6064
#       sum adj cols: 0
# Error at: 6065
#       sum adj cols: 0
# Error at: 6066
#       sum adj cols: 0
# Error at: 6067
#       sum adj cols: 0
# Error at: 6068
#       sum adj cols: 0
# Error at: 6069
#       sum adj cols: 0
# Error at: 6070
#       sum adj cols: 0
# Error at: 6071
#       sum adj cols: 0
# Error at: 6072
#       sum adj cols: 0
# Error at: 6150
#       sum adj cols: 0
# Error at: 6416
#       sum adj cols: 0
# Error at: 6417
#       sum adj cols: 0
# Error at: 6418
#       sum adj cols: 0
# Error at: 6419
#       sum adj cols: 0
# Error at: 6420
#       sum adj cols: 0
# Error at: 6421
#       sum adj cols: 0
# Error at: 6422
#       sum adj cols: 0
# Error at: 6423
#       sum adj cols: 0
# Error at: 6424
#       sum adj cols: 0
# Error at: 6425
#       sum adj cols: 0
# Error at: 6755
#       sum adj cols: 0
# Error at: 7533
#       sum adj cols: 0
# Error at: 8556
#       sum adj cols: 0
# Error at: 8557
#       sum adj cols: 0
# Error at: 8558
#       sum adj cols: 0
# Error at: 8559
#       sum adj cols: 0
# Error at: 8560
#       sum adj cols: 0
# Error at: 8561
#       sum adj cols: 0
# Error at: 8562
#       sum adj cols: 0
# Error at: 8563
#       sum adj cols: 0
# Error at: 8678
#       sum adj cols: 0
# Error at: 9089
#       sum adj cols: 0
# Error at: 9090
#       sum adj cols: 0
# Error at: 10611
#       sum adj cols: 0
# Error at: 10612
#       sum adj cols: 0
# Error at: 10613
#       sum adj cols: 0
# Error at: 10614
#       sum adj cols: 0
# Error at: 10615
#       sum adj cols: 0
# Error at: 10816
#       sum adj cols: 0
# Error at: 10912
#       sum adj cols: 0
# Error at: 10924
#       sum adj cols: 0
# Error at: 11020
#       sum adj cols: 0
# Error at: 11032
#       sum adj cols: 0
# Error at: 11044
#       sum adj cols: 0
# Error at: 11056
#       sum adj cols: 0
# Error at: 11068
#       sum adj cols: 0
# Error at: 11164
#       sum adj cols: 0
# Error at: 11176
#       sum adj cols: 0
# Error at: 11188
#       sum adj cols: 0
# Error at: 11200
#       sum adj cols: 0
# Error at: 11212
#       sum adj cols: 0
# Error at: 11270
#       sum adj cols: 0
# Error at: 11296
#       sum adj cols: 0
# Error at: 11308
#       sum adj cols: 0
# Error at: 11320
#       sum adj cols: 0
# Error at: 11332
#       sum adj cols: 0
# Error at: 11344
#       sum adj cols: 0
# Error at: 11356
#       sum adj cols: 0
# Error at: 11440
#       sum adj cols: 0
# Error at: 11452
#       sum adj cols: 0
# Error at: 11476
#       sum adj cols: 0
# Error at: 11500
#       sum adj cols: 0
# Error at: 11512
#       sum adj cols: 0
# Error at: 11524
#       sum adj cols: 0
# Error at: 11536
#       sum adj cols: 0
# Error at: 11548
#       sum adj cols: 0
# Error at: 11560
#       sum adj cols: 0
# Error at: 11572
#       sum adj cols: 0
# Error at: 11584
#       sum adj cols: 0
# Error at: 11596
#       sum adj cols: 0
# Error at: 11607
#       sum adj cols: 0
# Error at: 11608
#       sum adj cols: 0
# Error at: 11609
#       sum adj cols: 0
# Error at: 11610
#       sum adj cols: 0
# Error at: 11611
#       sum adj cols: 0
# Error at: 11612
#       sum adj cols: 0
# Error at: 11613
#       sum adj cols: 0
# Error at: 11614
#       sum adj cols: 0
# Error at: 11615
#       sum adj cols: 0
# Error at: 11616
#       sum adj cols: 0
# Error at: 11620
#       sum adj cols: 0
# Error at: 11632
#       sum adj cols: 0
# Error at: 11644
#       sum adj cols: 0
# Error at: 11656
#       sum adj cols: 0
# Error at: 11668
#       sum adj cols: 0
# Error at: 11680
#       sum adj cols: 0
# Error at: 11692
#       sum adj cols: 0
# Error at: 11704
#       sum adj cols: 0
# Error at: 11716
#       sum adj cols: 0
# Error at: 11722
#       sum adj cols: 0
# Error at: 11734
#       sum adj cols: 0
# Error at: 11746
#       sum adj cols: 0
# Error at: 11758
#       sum adj cols: 0
# Error at: 11770
#       sum adj cols: 0
# Error at: 11782
#       sum adj cols: 0
# Error at: 11794
#       sum adj cols: 0
# Error at: 11806
#       sum adj cols: 0
# Error at: 11818
#       sum adj cols: 0
# Error at: 11830
#       sum adj cols: 0
# Error at: 11842
#       sum adj cols: 0
# Error at: 11854
#       sum adj cols: 0
# Error at: 11866
#       sum adj cols: 0
# Error at: 11878
#       sum adj cols: 0
# Error at: 11890
#       sum adj cols: 0
# Error at: 11902
#       sum adj cols: 0
# Error at: 11914
#       sum adj cols: 0
# Error at: 11926
#       sum adj cols: 0
# Error at: 12009
#       sum adj cols: 0
# Error at: 12010
#       sum adj cols: 0
# Error at: 12011
#       sum adj cols: 0
# Error at: 12012
#       sum adj cols: 0
# Error at: 12013
#       sum adj cols: 0
# Error at: 12014
#       sum adj cols: 0
# Error at: 12015
#       sum adj cols: 0
# Error at: 12016
#       sum adj cols: 0
# Error at: 12017
#       sum adj cols: 0
# Error at: 12018
#       sum adj cols: 0
# Error at: 12019
#       sum adj cols: 0
# Error at: 12020
#       sum adj cols: 0
# Error at: 12021
#       sum adj cols: 0
# Error at: 12022
#       sum adj cols: 0
# Error at: 12023
#       sum adj cols: 0
# Error at: 12024
#       sum adj cols: 0
# Error at: 12025
#       sum adj cols: 0
# Error at: 12026
#       sum adj cols: 0
# Error at: 12027
#       sum adj cols: 0
# Error at: 12028
#       sum adj cols: 0
# Error at: 12029
#       sum adj cols: 0
# Error at: 12030
#       sum adj cols: 0
# Error at: 12031
#       sum adj cols: 0
# Error at: 12032
#       sum adj cols: 0
# Error at: 12033
#       sum adj cols: 0
# Error at: 12034
#       sum adj cols: 0
# Error at: 12035
#       sum adj cols: 0
# Error at: 12036
#       sum adj cols: 0
# Error at: 12037
#       sum adj cols: 0
# Error at: 12038
#       sum adj cols: 0
# Error at: 12039
#       sum adj cols: 0
# Error at: 12040
#       sum adj cols: 0
# Error at: 12041
#       sum adj cols: 0
# Error at: 12042
#       sum adj cols: 0
# Error at: 12043
#       sum adj cols: 0
# Error at: 12044
#       sum adj cols: 0
# Error at: 12045
#       sum adj cols: 0
# Error at: 12046
#       sum adj cols: 0
# Error at: 12047
#       sum adj cols: 0
# Error at: 12048
#       sum adj cols: 0
# Error at: 12049
#       sum adj cols: 0
# Error at: 12050
#       sum adj cols: 0
# Error at: 12051
#       sum adj cols: 0
# Error at: 12052
#       sum adj cols: 0
# Error at: 12053
#       sum adj cols: 0
# Error at: 12054
#       sum adj cols: 0
# Error at: 12055
#       sum adj cols: 0
# Error at: 12056
#       sum adj cols: 0
# Error at: 12057
#       sum adj cols: 0
# Error at: 12058
#       sum adj cols: 0
# Error at: 12059
#       sum adj cols: 0
# Error at: 12060
#       sum adj cols: 0
# Error at: 12061
#       sum adj cols: 0
# Error at: 13994
#       sum adj cols: 0
# Error at: 14006
#       sum adj cols: 0
# Error at: 14018
#       sum adj cols: 0
# Error at: 14030
#       sum adj cols: 0
# Error at: 14102
#       sum adj cols: 0
# Error at: 14138
#       sum adj cols: 0
# Error at: 14150
#       sum adj cols: 0
# Error at: 14186
#       sum adj cols: 0
# Error at: 15273
#       sum adj cols: 0
# Error at: 15417
#       sum adj cols: 0
# Error at: 15418
#       sum adj cols: 0
# Error at: 15419
#       sum adj cols: 0
# Error at: 15420
#       sum adj cols: 0
# Error at: 15421
#       sum adj cols: 0
# Error at: 15841
#       sum adj cols: 0
# Error at: 15943
#       sum adj cols: 0
# Error at: 16465
#       sum adj cols: 0
# Error at: 16466
#       sum adj cols: 0
# Error at: 16492
#       sum adj cols: 0
# Error at: 16498
#       sum adj cols: 0
# Error at: 16499
#       sum adj cols: 0
# Error at: 16500
#       sum adj cols: 0
# Error at: 16501
#       sum adj cols: 0
# Error at: 16502
#       sum adj cols: 0
# Error at: 16503
#       sum adj cols: 0
# Error at: 16504
#       sum adj cols: 0
# Error at: 16505
#       sum adj cols: 0
# Error at: 16506
#       sum adj cols: 0
# Error at: 16507
#       sum adj cols: 0
# Error at: 16508
#       sum adj cols: 0
# Error at: 16509
#       sum adj cols: 0
# Error at: 16510
#       sum adj cols: 0
# Error at: 16512
#       sum adj cols: 0
# Error at: 16513
#       sum adj cols: 0
# Error at: 16514
#       sum adj cols: 0
# Error at: 16515
#       sum adj cols: 0
# Error at: 16516
#       sum adj cols: 0
# Error at: 16517
#       sum adj cols: 0
# Error at: 16518
#       sum adj cols: 0
# Error at: 16531
#       sum adj cols: 0
# Error at: 16535
#       sum adj cols: 0
# Error at: 16536
#       sum adj cols: 0
# Error at: 16537
#       sum adj cols: 0
# Error at: 16538
#       sum adj cols: 0
# Error at: 16539
#       sum adj cols: 0
# Error at: 16540
#       sum adj cols: 0
# Error at: 16556
#       sum adj cols: 0
# Error at: 16557
#       sum adj cols: 0
# Error at: 16558
#       sum adj cols: 0
# Error at: 16559
#       sum adj cols: 0
# Error at: 16560
#       sum adj cols: 0
# Error at: 16561
#       sum adj cols: 0
# Error at: 16562
#       sum adj cols: 0
# Error at: 16563
#       sum adj cols: 0
# Error at: 16564
#       sum adj cols: 0
# Error at: 16565
#       sum adj cols: 0
# Error at: 16566
#       sum adj cols: 0
# Error at: 16567
#       sum adj cols: 0
# Error at: 16568
#       sum adj cols: 0
# Error at: 16569
#       sum adj cols: 0
# Error at: 16570
#       sum adj cols: 0
# Error at: 16571
#       sum adj cols: 0
# Error at: 16572
#       sum adj cols: 0
# Error at: 16573
#       sum adj cols: 0
# Error at: 16574
#       sum adj cols: 0
# Error at: 16575
#       sum adj cols: 0
# Error at: 16576
#       sum adj cols: 0
# Error at: 16577
#       sum adj cols: 0
# Error at: 16578
#       sum adj cols: 0
# Error at: 16579
#       sum adj cols: 0
# Error at: 16580
#       sum adj cols: 0
# Error at: 17338
#       sum adj cols: 0
# Error at: 18812
#       sum adj cols: 0
# Error at: 18990
#       sum adj cols: 0
# Error at: 18991
#       sum adj cols: 0
# Error at: 18994
#       sum adj cols: 0
# Error at: 18995
#       sum adj cols: 0
# Error at: 18996
#       sum adj cols: 0
# Error at: 19038
#       sum adj cols: 0
# Error at: 19043
#       sum adj cols: 0
# Error at: 19044
#       sum adj cols: 0
# Error at: 19045
#       sum adj cols: 0
# Error at: 19046
#       sum adj cols: 0
# Error at: 19047
#       sum adj cols: 0
# Error at: 19048
#       sum adj cols: 0
# Error at: 19049
#       sum adj cols: 0
# Error at: 19050
#       sum adj cols: 0
# Error at: 19051
#       sum adj cols: 0
# Error at: 19064
#       sum adj cols: 0
# Error at: 20074
#       sum adj cols: 0
# Error at: 20075
#       sum adj cols: 0
# Error at: 20076
#       sum adj cols: 0
# Error at: 20077
#       sum adj cols: 0
# Error at: 20078
#       sum adj cols: 0
# Error at: 20079
#       sum adj cols: 0
# Error at: 20080
#       sum adj cols: 0
# Error at: 20081
#       sum adj cols: 0
# Error at: 20082
#       sum adj cols: 0
# Error at: 20083
#       sum adj cols: 0
# Error at: 20084
#       sum adj cols: 0
# Error at: 21446
#       sum adj cols: 0
# Error at: 21449
#       sum adj cols: 0
# Error at: 21450
#       sum adj cols: 0
# Error at: 22112
#       sum adj cols: 0
# Error at: 22113
#       sum adj cols: 0
# Error at: 22114
#       sum adj cols: 0
# Error at: 22115
#       sum adj cols: 0
# Error at: 22116
#       sum adj cols: 0
# Error at: 22117
#       sum adj cols: 0
# Error at: 22178
#       sum adj cols: 0
# Error at: 22179
#       sum adj cols: 0
# Error at: 22180
#       sum adj cols: 0
# Error at: 22181
#       sum adj cols: 0
# Error at: 22182
#       sum adj cols: 0
# Error at: 22183
#       sum adj cols: 0
# Error at: 22184
#       sum adj cols: 0
# Error at: 22185
#       sum adj cols: 0
# Error at: 22186
#       sum adj cols: 0
# Error at: 22187
#       sum adj cols: 0
# Error at: 22188
#       sum adj cols: 0
# Error at: 22189
#       sum adj cols: 0
# Error at: 22600
#       sum adj cols: 0
# Error at: 22601
#       sum adj cols: 0
# Error at: 22604
#       sum adj cols: 0
# Error at: 22605
#       sum adj cols: 0
# Error at: 22606
#       sum adj cols: 0
# Error at: 22607
#       sum adj cols: 0
# Error at: 22610
#       sum adj cols: 0
# Error at: 22611
#       sum adj cols: 0
# Error at: 22612
#       sum adj cols: 0
# Error at: 22613
#       sum adj cols: 0
# Error at: 22658
#       sum adj cols: 0
# Error at: 22748
#       sum adj cols: 0
# Error at: 22749
#       sum adj cols: 0
# Error at: 22750
#       sum adj cols: 0
# Error at: 22790
#       sum adj cols: 0
# Error at: 22791
#       sum adj cols: 0
# Error at: 22792
#       sum adj cols: 0
# Error at: 22793
#       sum adj cols: 0
# Error at: 22794
#       sum adj cols: 0
# Error at: 22795
#       sum adj cols: 0
# Error at: 22796
#       sum adj cols: 0
# Error at: 22994
#       sum adj cols: 0
# Error at: 22997
#       sum adj cols: 0
# Error at: 23318
#       sum adj cols: 0
# Error at: 23319
#       sum adj cols: 0
# Error at: 23320
#       sum adj cols: 0
# Error at: 23321
#       sum adj cols: 0
# Error at: 23322
#       sum adj cols: 0
# Error at: 23323
#       sum adj cols: 0
# Error at: 23324
#       sum adj cols: 0
# Error at: 23325
#       sum adj cols: 0
# Error at: 23326
#       sum adj cols: 0
# Error at: 23327
#       sum adj cols: 0
# Error at: 23329
#       sum adj cols: 0
# Error at: 23786
#       sum adj cols: 0
# Error at: 23787
#       sum adj cols: 0
# Error at: 23788
#       sum adj cols: 0
# Error at: 24479
#       sum adj cols: 0
# Error at: 24480
#       sum adj cols: 0
# Error at: 24481
#       sum adj cols: 0
# Error at: 24482
#       sum adj cols: 0
# Error at: 24483
#       sum adj cols: 0
# Error at: 24484
#       sum adj cols: 0
# Error at: 24551
#       sum adj cols: 0
# Error at: 24552
#       sum adj cols: 0
# Error at: 24553
#       sum adj cols: 0
# Error at: 25493
#       sum adj cols: 0
# Error at: 25494
#       sum adj cols: 0
# Error at: 25495
#       sum adj cols: 0
# Error at: 25496
#       sum adj cols: 0
# Error at: 25498
#       sum adj cols: 0
# Error at: 25559
#       sum adj cols: 0
# Error at: 25560
#       sum adj cols: 0
# Error at: 25561
#       sum adj cols: 0
# Error at: 25562
#       sum adj cols: 0
# Error at: 25563
#       sum adj cols: 0
# Error at: 25564
#       sum adj cols: 0
# Error at: 25565
#       sum adj cols: 0
# Error at: 25602
#       sum adj cols: 0
# Error at: 25603
#       sum adj cols: 0
# Error at: 25834
#       sum adj cols: 0
# Error at: 25835
#       sum adj cols: 0
# Error at: 25836
#       sum adj cols: 0
# Error at: 25837
#       sum adj cols: 0
# Error at: 25838
#       sum adj cols: 0
# Error at: 26384
#       sum adj cols: 0
# Error at: 26385
#       sum adj cols: 0
# Error at: 26390
#       sum adj cols: 0
# Error at: 26391
#       sum adj cols: 0
# Error at: 26633
#       sum adj cols: 0
# Error at: 26634
#       sum adj cols: 0
# Error at: 26635
#       sum adj cols: 0
# Error at: 26639
#       sum adj cols: 0
# Error at: 26640
#       sum adj cols: 0
# Error at: 26641
#       sum adj cols: 0
# Error at: 26642
#       sum adj cols: 0
# Error at: 26687
#       sum adj cols: 0
# Error at: 26688
#       sum adj cols: 0
# Error at: 26699
#       sum adj cols: 0
# Error at: 26700
#       sum adj cols: 0
# Error at: 26701
#       sum adj cols: 0
# Error at: 26702
#       sum adj cols: 0
# Error at: 26703
#       sum adj cols: 0
# Error at: 26704
#       sum adj cols: 0
# Error at: 26705
#       sum adj cols: 0
# Error at: 26706
#       sum adj cols: 0
# Error at: 26707
#       sum adj cols: 0
# Error at: 26708
#       sum adj cols: 0
# Error at: 27053
#       sum adj cols: 0
# Error at: 27054
#       sum adj cols: 0
# Error at: 27055
#       sum adj cols: 0
# Error at: 27056
#       sum adj cols: 0
# Error at: 27057
#       sum adj cols: 0
# Error at: 27058
#       sum adj cols: 0
# Error at: 27059
#       sum adj cols: 0
# Error at: 27060
#       sum adj cols: 0
# Error at: 27061
#       sum adj cols: 0
# Error at: 27062
#       sum adj cols: 0
# Error at: 27063
#       sum adj cols: 0
# Error at: 27064
#       sum adj cols: 0
# Error at: 27065
#       sum adj cols: 0
# Error at: 27066
#       sum adj cols: 0
# Error at: 27067
#       sum adj cols: 0
# Error at: 27068
#       sum adj cols: 0
# Error at: 27069
#       sum adj cols: 0
# Error at: 27070
#       sum adj cols: 0
# Error at: 27071
#       sum adj cols: 0
# Error at: 27072
#       sum adj cols: 0
# Error at: 27073
#       sum adj cols: 0
# Error at: 27148
#       sum adj cols: 0
# Error at: 27149
#       sum adj cols: 0
# Error at: 27150
#       sum adj cols: 0
# Error at: 27158
#       sum adj cols: 0
# Error at: 27159
#       sum adj cols: 0
# Error at: 27160
#       sum adj cols: 0
# Error at: 27161
#       sum adj cols: 0
# Error at: 27162
#       sum adj cols: 0
# Error at: 27163
#       sum adj cols: 0
# Error at: 28647
#       sum adj cols: 0
# Error at: 28648
#       sum adj cols: 0
# Error at: 28649
#       sum adj cols: 0
# Error at: 28650
#       sum adj cols: 0
# Error at: 28651
#       sum adj cols: 0
# Error at: 28652
#       sum adj cols: 0
# Error at: 28653
#       sum adj cols: 0
# Error at: 28654
#       sum adj cols: 0
# Error at: 28655
#       sum adj cols: 0
# Error at: 28656
#       sum adj cols: 0
# Error at: 28697
#       sum adj cols: 0
# Error at: 30486
#       sum adj cols: 0
# Error at: 30487
#       sum adj cols: 0
# Error at: 30488
#       sum adj cols: 0
# Error at: 30489
#       sum adj cols: 0
# Error at: 30490
#       sum adj cols: 0
# Error at: 30745
#       sum adj cols: 0
# Error at: 30746
#       sum adj cols: 0
# Error at: 30747
#       sum adj cols: 0
# Error at: 30800
#       sum adj cols: 0
# Error at: 31128
#       sum adj cols: 0
# Error at: 31129
#       sum adj cols: 0
# Error at: 31130
#       sum adj cols: 0
# Error at: 31131
#       sum adj cols: 0
# Error at: 31132
#       sum adj cols: 0
# Error at: 31133
#       sum adj cols: 0
# Error at: 31134
#       sum adj cols: 0
# Error at: 31135
#       sum adj cols: 0
# Error at: 31148
#       sum adj cols: 0
# Error at: 31151
#       sum adj cols: 0
# Error at: 31154
#       sum adj cols: 0
# Error at: 31158
#       sum adj cols: 0
# Error at: 31159
#       sum adj cols: 0
# Error at: 31160
#       sum adj cols: 0
# Error at: 31182
#       sum adj cols: 0
# Error at: 31183
#       sum adj cols: 0
# Error at: 31995
#       sum adj cols: 0
# Error at: 32275
#       sum adj cols: 0
# Error at: 32971
#       sum adj cols: 0
# Error at: 32972
#       sum adj cols: 0
# Error at: 32975
#       sum adj cols: 0
# Error at: 32976
#       sum adj cols: 0
# Error at: 32977
#       sum adj cols: 0
# Error at: 32978
#       sum adj cols: 0
# Error at: 32979
#       sum adj cols: 0
# Error at: 32981
#       sum adj cols: 0
# Error at: 32982
#       sum adj cols: 0
# Error at: 32983
#       sum adj cols: 0
# Error at: 32984
#       sum adj cols: 0
# Error at: 32985
#       sum adj cols: 0
# Error at: 32986
#       sum adj cols: 0
# Error at: 32987
#       sum adj cols: 0
# Error at: 32988
#       sum adj cols: 0
# Error at: 32989
#       sum adj cols: 0
# Error at: 32990
#       sum adj cols: 0
# Error at: 33035
#       sum adj cols: 0
# Error at: 33036
#       sum adj cols: 0
# Error at: 33037
#       sum adj cols: 0
# Error at: 33038
#       sum adj cols: 0
# Error at: 33039
#       sum adj cols: 0
# Error at: 33040
#       sum adj cols: 0
# Error at: 33041
#       sum adj cols: 0
# Error at: 33042
#       sum adj cols: 0
# Error at: 33043
#       sum adj cols: 0
# Error at: 33044
#       sum adj cols: 0
# Error at: 33045
#       sum adj cols: 0
# Error at: 33046
#       sum adj cols: 0
# Error at: 33058
#       sum adj cols: 0
# Error at: 33621
#       sum adj cols: 0
# Error at: 34136
#       sum adj cols: 0
# Error at: 34137
#       sum adj cols: 0
# Error at: 34138
#       sum adj cols: 0
# Error at: 34139
#       sum adj cols: 0
# Error at: 34140
#       sum adj cols: 0
# Error at: 34141
#       sum adj cols: 0
# Error at: 34142
#       sum adj cols: 0
# Error at: 34143
#       sum adj cols: 0
# Error at: 34144
#       sum adj cols: 0
# Error at: 34145
#       sum adj cols: 0
# Error at: 34146
#       sum adj cols: 0
# Error at: 34147
#       sum adj cols: 0
# Error at: 34148
#       sum adj cols: 0
# Error at: 34968
#       sum adj cols: 0
# Error at: 34969
#       sum adj cols: 0
# Error at: 35476
#       sum adj cols: 0
# Error at: 35597
#       sum adj cols: 0
# Error at: 35598
#       sum adj cols: 0
# Error at: 35599
#       sum adj cols: 0
# Error at: 35830
#       sum adj cols: 0
# Error at: 35831
#       sum adj cols: 0
# Error at: 35832
#       sum adj cols: 0
# Error at: 35833
#       sum adj cols: 0
# Error at: 35834
#       sum adj cols: 0
# Error at: 35835
#       sum adj cols: 0
# Error at: 35836
#       sum adj cols: 0
# Error at: 35837
#       sum adj cols: 0
# Error at: 35838
#       sum adj cols: 0
# Error at: 35839
#       sum adj cols: 0
# Error at: 37609
#       sum adj cols: 0
# Error at: 37610
#       sum adj cols: 0
# Error at: 37611
#       sum adj cols: 0
# Error at: 37612
#       sum adj cols: 0
# Error at: 37613
#       sum adj cols: 0
# Error at: 38449
#       sum adj cols: 0
# Error at: 38593
#       sum adj cols: 0
# Error at: 38594
#       sum adj cols: 0
# Error at: 38595
#       sum adj cols: 0
# Error at: 38689
#       sum adj cols: 0
# Error at: 38690
#       sum adj cols: 0
# Error at: 38691
#       sum adj cols: 0
# Error at: 38692
#       sum adj cols: 0
# Error at: 38693
#       sum adj cols: 0
# Error at: 38750
#       sum adj cols: 0
# Error at: 38751
#       sum adj cols: 0
# Error at: 38752
#       sum adj cols: 0
# Error at: 38753
#       sum adj cols: 0
# Error at: 38770
#       sum adj cols: 0
# Error at: 38771
#       sum adj cols: 0
# Error at: 38776
#       sum adj cols: 0
# Error at: 38777
#       sum adj cols: 0
# Error at: 40560
#       sum adj cols: 0
# Error at: 40561
#       sum adj cols: 0
# Error at: 40562
#       sum adj cols: 0
# Error at: 40563
#       sum adj cols: 0
# Error at: 40564
#       sum adj cols: 0
# Error at: 40565
#       sum adj cols: 0
# Error at: 40566
#       sum adj cols: 0
# Error at: 41444
#       sum adj cols: 0
# Error at: 41445
#       sum adj cols: 0
# Error at: 41446
#       sum adj cols: 0
# Error at: 41447
#       sum adj cols: 0
# Error at: 41448
#       sum adj cols: 0
# Error at: 41449
#       sum adj cols: 0
# Error at: 41450
#       sum adj cols: 0
# Error at: 41451
#       sum adj cols: 0
# Error at: 41452
#       sum adj cols: 0
# Error at: 41453
#       sum adj cols: 0
# Error at: 41473
#       sum adj cols: 0
# Error at: 41474
#       sum adj cols: 0
# Error at: 41737
#       sum adj cols: 0
# Error at: 43046
#       sum adj cols: 0
# Error at: 43260
#       sum adj cols: 0
# Error at: 43261
#       sum adj cols: 0
# Error at: 43262
#       sum adj cols: 0
# Error at: 43263
#       sum adj cols: 0
# Error at: 43264
#       sum adj cols: 0
# Error at: 43265
#       sum adj cols: 0
# Error at: 43266
#       sum adj cols: 0
# Error at: 43267
#       sum adj cols: 0
# Error at: 43268
#       sum adj cols: 0
# Error at: 43269
#       sum adj cols: 0
# Error at: 43270
#       sum adj cols: 0
# Error at: 43271
#       sum adj cols: 0
# Error at: 43272
#       sum adj cols: 0
# Error at: 43273
#       sum adj cols: 0
# Error at: 43274
#       sum adj cols: 0
# Error at: 43275
#       sum adj cols: 0
# Error at: 43276
#       sum adj cols: 0
# Error at: 43277
#       sum adj cols: 0
# Error at: 43278
#       sum adj cols: 0
# Error at: 43279
#       sum adj cols: 0
# Error at: 43280
#       sum adj cols: 0
# Error at: 43281
#       sum adj cols: 0
# Error at: 43282
#       sum adj cols: 0
# Error at: 43283
#       sum adj cols: 0
# Error at: 43284
#       sum adj cols: 0
# Error at: 43285
#       sum adj cols: 0
# Error at: 43286
#       sum adj cols: 0
# Error at: 43287
#       sum adj cols: 0
# Error at: 43288
#       sum adj cols: 0
# Error at: 43289
#       sum adj cols: 0
# Error at: 43290
#       sum adj cols: 0
# Error at: 43291
#       sum adj cols: 0
# Error at: 43292
#       sum adj cols: 0
# Error at: 43293
#       sum adj cols: 0
# Error at: 43294
#       sum adj cols: 0
# Error at: 43295
#       sum adj cols: 0
# Error at: 43296
#       sum adj cols: 0
# Error at: 43297
#       sum adj cols: 0
# Error at: 43298
#       sum adj cols: 0
# Error at: 43299
#       sum adj cols: 0
# Error at: 43300
#       sum adj cols: 0
# Error at: 43301
#       sum adj cols: 0
# Error at: 43302
#       sum adj cols: 0
# Error at: 43303
#       sum adj cols: 0
# Error at: 43712
#       sum adj cols: 0
# Error at: 43713
#       sum adj cols: 0
# Error at: 43722
#       sum adj cols: 0
# Error at: 44007
#       sum adj cols: 0
# Error at: 44008
#       sum adj cols: 0
# Error at: 44009
#       sum adj cols: 0
# Error at: 44010
#       sum adj cols: 0
# Error at: 44669
#       sum adj cols: 0
# Error at: 44670
#       sum adj cols: 0
# Error at: 44671
#       sum adj cols: 0
# Error at: 44702
#       sum adj cols: 0
# Error at: 45800
#       sum adj cols: 0
# Error at: 47950
#       sum adj cols: 0
# Error at: 47951
#       sum adj cols: 0
# Error at: 47952
#       sum adj cols: 0
# Error at: 47953
#       sum adj cols: 0
# Error at: 47964
#       sum adj cols: 0
# Error at: 47965
#       sum adj cols: 0
# Error at: 47968
#       sum adj cols: 0
# Error at: 47969
#       sum adj cols: 0
# Error at: 47970
#       sum adj cols: 0
# Error at: 47971
#       sum adj cols: 0
# Error at: 48707
#       sum adj cols: 0
# Error at: 48708
#       sum adj cols: 0
# Error at: 48720
#       sum adj cols: 0
# Error at: 48725
#       sum adj cols: 0
# Error at: 48732
#       sum adj cols: 0
# Error at: 48865
#       sum adj cols: 0
# Error at: 48869
#       sum adj cols: 0
# Error at: 48876
#       sum adj cols: 0
# Error at: 48881
#       sum adj cols: 0
# Error at: 48972
#       sum adj cols: 0
# Error at: 48977
#       sum adj cols: 0
# Error at: 49306
#       sum adj cols: 0
# Error at: 49307
#       sum adj cols: 0
# Error at: 49308
#       sum adj cols: 0
# Error at: 49309
#       sum adj cols: 0
# Error at: 49310
#       sum adj cols: 0
# Error at: 50013
#       sum adj cols: 0
# Error at: 50014
#       sum adj cols: 0
# Error at: 50015
#       sum adj cols: 0
# Error at: 50016
#       sum adj cols: 0
# Error at: 50017
#       sum adj cols: 0
# Error at: 50020
#       sum adj cols: 0
# Error at: 50021
#       sum adj cols: 0
# Error at: 50022
#       sum adj cols: 0
# Error at: 50023
#       sum adj cols: 0
# Error at: 50024
#       sum adj cols: 0
# Error at: 50025
#       sum adj cols: 0
# Error at: 50026
#       sum adj cols: 0
# Error at: 50027
#       sum adj cols: 0
# Error at: 50028
#       sum adj cols: 0
# Error at: 50029
#       sum adj cols: 0
# Error at: 50155
#       sum adj cols: 0
# Error at: 50156
#       sum adj cols: 0
# Error at: 50160
#       sum adj cols: 0
# Error at: 51728
#       sum adj cols: 0
# Error at: 51729
#       sum adj cols: 0
# Error at: 51730
#       sum adj cols: 0
# Error at: 51731
#       sum adj cols: 0
# Error at: 51732
#       sum adj cols: 0
# Error at: 51733
#       sum adj cols: 0
# Error at: 51734
#       sum adj cols: 0
# Error at: 51735
#       sum adj cols: 0
# Error at: 51736
#       sum adj cols: 0
# Error at: 51737
#       sum adj cols: 0
# Error at: 51996
#       sum adj cols: 0
# Error at: 53059
#       sum adj cols: 0
# Error at: 53060
#       sum adj cols: 0
# Error at: 53061
#       sum adj cols: 0
# Error at: 53062
#       sum adj cols: 0
# Error at: 53063
#       sum adj cols: 0
# Error at: 53064
#       sum adj cols: 0
# Error at: 53065
#       sum adj cols: 0
# Error at: 53066
#       sum adj cols: 0
# Error at: 53067
#       sum adj cols: 0
# Error at: 53068
#       sum adj cols: 0
# Error at: 53069
#       sum adj cols: 0
# Error at: 53612
#       sum adj cols: 0
# Error at: 54040
#       sum adj cols: 0
# Error at: 54041
#       sum adj cols: 0
# Error at: 55538
#       sum adj cols: 0
# Error at: 55539
#       sum adj cols: 0
# Error at: 55540
#       sum adj cols: 0
# Error at: 55541
#       sum adj cols: 0
# Error at: 55542
#       sum adj cols: 0
# Error at: 55543
#       sum adj cols: 0
# Error at: 55544
#       sum adj cols: 0
# Error at: 55545
#       sum adj cols: 0
# Error at: 55546
#       sum adj cols: 0
# Error at: 55547
#       sum adj cols: 0
# Error at: 56662
#       sum adj cols: 0
# Error at: 56871
#       sum adj cols: 0
# Error at: 57064
#       sum adj cols: 0
# Error at: 57534
#       sum adj cols: 0
# Error at: 57817
#       sum adj cols: 0
# Error at: 57818
#       sum adj cols: 0
# Error at: 57819
#       sum adj cols: 0
# Error at: 57820
#       sum adj cols: 0
# Error at: 57821
#       sum adj cols: 0
# Error at: 57822
#       sum adj cols: 0
# Error at: 57823
#       sum adj cols: 0
# Error at: 57824
#       sum adj cols: 0
# Error at: 57825
#       sum adj cols: 0
# Error at: 57826
#       sum adj cols: 0
# Error at: 57827
#       sum adj cols: 0
# Error at: 57828
#       sum adj cols: 0
# Error at: 57829
#       sum adj cols: 0
# Error at: 57830
#       sum adj cols: 0
# Error at: 57831
#       sum adj cols: 0
# Error at: 57832
#       sum adj cols: 0
# Error at: 57833
#       sum adj cols: 0
# Error at: 57834
#       sum adj cols: 0
# Error at: 57835
#       sum adj cols: 0
# Error at: 57836
#       sum adj cols: 0
# Error at: 57837
#       sum adj cols: 0
# Error at: 57838
#       sum adj cols: 0
# Error at: 57839
#       sum adj cols: 0
# Error at: 57840
#       sum adj cols: 0
# Error at: 58052
#       sum adj cols: 0
# Error at: 58053
#       sum adj cols: 0
# Error at: 58054
#       sum adj cols: 0
# Error at: 58055
#       sum adj cols: 0
# Error at: 58056
#       sum adj cols: 0
# Error at: 58057
#       sum adj cols: 0
# Error at: 58058
#       sum adj cols: 0
# Error at: 58059
#       sum adj cols: 0
# Error at: 58060
#       sum adj cols: 0
# Error at: 58061
#       sum adj cols: 0
# Error at: 58232
#       sum adj cols: 0
# Error at: 58233
#       sum adj cols: 0
# Error at: 58234
#       sum adj cols: 0
# Error at: 58235
#       sum adj cols: 0
# Error at: 58236
#       sum adj cols: 0
# Error at: 58237
#       sum adj cols: 0
# Error at: 58238
#       sum adj cols: 0
# Error at: 58239
#       sum adj cols: 0
# Error at: 58240
#       sum adj cols: 0
# Error at: 58241
#       sum adj cols: 0
# Error at: 58454
#       sum adj cols: 0
# Error at: 58670
#       sum adj cols: 0
# Error at: 58671
#       sum adj cols: 0
# Error at: 60242
#       sum adj cols: 0
# Error at: 60243
#       sum adj cols: 0
# Error at: 60244
#       sum adj cols: 0
# Error at: 60245
#       sum adj cols: 0
# Error at: 60246
#       sum adj cols: 0
# Error at: 60247
#       sum adj cols: 0
# Error at: 60248
#       sum adj cols: 0
# Error at: 60249
#       sum adj cols: 0
# Error at: 60250
#       sum adj cols: 0
# Error at: 60251
#       sum adj cols: 0
# Error at: 60373
#       sum adj cols: 0
# Error at: 60505
#       sum adj cols: 0
# Error at: 60506
#       sum adj cols: 0
# Error at: 60511
#       sum adj cols: 0
# Error at: 60688
#       sum adj cols: 0
# Error at: 60689
#       sum adj cols: 0
# Error at: 60690
#       sum adj cols: 0
# Error at: 60691
#       sum adj cols: 0
# Error at: 60692
#       sum adj cols: 0
# Error at: 60693
#       sum adj cols: 0
# Error at: 60828
#       sum adj cols: 0
# Error at: 60829
#       sum adj cols: 0
# Error at: 60830
#       sum adj cols: 0
# Error at: 60831
#       sum adj cols: 0
# Error at: 61308
#       sum adj cols: 0
# Error at: 61309
#       sum adj cols: 0
# Error at: 61310
#       sum adj cols: 0
# Error at: 61311
#       sum adj cols: 0
# Error at: 61314
#       sum adj cols: 0
# Error at: 61315
#       sum adj cols: 0
# Error at: 61316
#       sum adj cols: 0
# Error at: 61317
#       sum adj cols: 0
# Error at: 62011
#       sum adj cols: 0
# Error at: 62012
#       sum adj cols: 0
# Error at: 62013
#       sum adj cols: 0
# Error at: 62014
#       sum adj cols: 0
# Error at: 62015
#       sum adj cols: 0
# Error at: 62058
#       sum adj cols: 0
# Error at: 62059
#       sum adj cols: 0
# Error at: 62060
#       sum adj cols: 0
# Error at: 62061
#       sum adj cols: 0
# Error at: 62062
#       sum adj cols: 0
# Error at: 62063
#       sum adj cols: 0
# Error at: 62079
#       sum adj cols: 0
# Error at: 62081
#       sum adj cols: 0
# Error at: 62082
#       sum adj cols: 0
# Error at: 62126
#       sum adj cols: 0
# Error at: 62127
#       sum adj cols: 0
# Error at: 62128
#       sum adj cols: 0
# Error at: 62129
#       sum adj cols: 0
# Error at: 62136
#       sum adj cols: 0
# Error at: 62220
#       sum adj cols: 0
# Error at: 62224
#       sum adj cols: 0
# Error at: 62225
#       sum adj cols: 0
# Error at: 62456
#       sum adj cols: 0
# Error at: 62618
#       sum adj cols: 0
# Error at: 62619
#       sum adj cols: 0
# Error at: 62620
#       sum adj cols: 0
# Error at: 62621
#       sum adj cols: 0
# Error at: 62956
#       sum adj cols: 0
# Error at: 63434
#       sum adj cols: 0
# Error at: 63435
#       sum adj cols: 0
# Error at: 63436
#       sum adj cols: 0
# Error at: 63437
#       sum adj cols: 0
# Error at: 63438
#       sum adj cols: 0
# Error at: 63439
#       sum adj cols: 0
# Error at: 63440
#       sum adj cols: 0
# Error at: 63441
#       sum adj cols: 0
# Error at: 63442
#       sum adj cols: 0
# Error at: 63443
#       sum adj cols: 0
# Error at: 63460
#       sum adj cols: 0
# Error at: 63511
#       sum adj cols: 0
# Error at: 63845
#       sum adj cols: 0
# Error at: 63846
#       sum adj cols: 0
# Error at: 63847
#       sum adj cols: 0
# Error at: 63848
#       sum adj cols: 0
# Error at: 63849
#       sum adj cols: 0
# Error at: 63850
#       sum adj cols: 0
# Error at: 63851
#       sum adj cols: 0
# Error at: 63852
#       sum adj cols: 0
# Error at: 63853
#       sum adj cols: 0
# Error at: 63854
#       sum adj cols: 0
# Error at: 63855
#       sum adj cols: 0
# Error at: 63856
#       sum adj cols: 0
# Error at: 63857
#       sum adj cols: 0
# Error at: 63962
#       sum adj cols: 0
# Error at: 63963
#       sum adj cols: 0
# Error at: 63964
#       sum adj cols: 0
# Error at: 63965
#       sum adj cols: 0
# Error at: 64056
#       sum adj cols: 0
# Error at: 64068
#       sum adj cols: 0
# Error at: 64080
#       sum adj cols: 0
# Error at: 64092
#       sum adj cols: 0
# Error at: 64663
#       sum adj cols: 0
# Error at: 64664
#       sum adj cols: 0
# Error at: 64665
#       sum adj cols: 0
# Error at: 64666
#       sum adj cols: 0
# Error at: 64667
#       sum adj cols: 0
# Error at: 64722
#       sum adj cols: 0
# Error at: 65000
#       sum adj cols: 0
# Error at: 65049
#       sum adj cols: 0
# Error at: 65267
#       sum adj cols: 0
# Error at: 65268
#       sum adj cols: 0
# Error at: 65269
#       sum adj cols: 0
# Error at: 65270
#       sum adj cols: 0
# Error at: 65279
#       sum adj cols: 0
# Error at: 65280
#       sum adj cols: 0
# Error at: 65281
#       sum adj cols: 0
# Error at: 65282
#       sum adj cols: 0
# Error at: 65292
#       sum adj cols: 0
# Error at: 65293
#       sum adj cols: 0
# Error at: 65294
#       sum adj cols: 0
# Error at: 65416
#       sum adj cols: 0
# Error at: 65417
#       sum adj cols: 0
# Error at: 65418
#       sum adj cols: 0
# Error at: 65419
#       sum adj cols: 0
# Error at: 65420
#       sum adj cols: 0
# Error at: 65421
#       sum adj cols: 0
# Error at: 65422
#       sum adj cols: 0
# Error at: 65423
#       sum adj cols: 0
# Error at: 65486
#       sum adj cols: 0
# Error at: 65628
#       sum adj cols: 0
# Error at: 66299
#       sum adj cols: 0
# Error at: 66300
#       sum adj cols: 0
# Error at: 66663
#       sum adj cols: 0
# Error at: 66664
#       sum adj cols: 0
# Error at: 66665
#       sum adj cols: 0
# Error at: 66666
#       sum adj cols: 0
# Error at: 66667
#       sum adj cols: 0
# Error at: 67140
#       sum adj cols: 0
# Error at: 67226
#       sum adj cols: 0
# Error at: 67227
#       sum adj cols: 0
# Error at: 67228
#       sum adj cols: 0
# Error at: 67229
#       sum adj cols: 0
# Error at: 68160
#       sum adj cols: 0
# Error at: 68260
#       sum adj cols: 0
# Error at: 68261
#       sum adj cols: 0
# Error at: 68262
#       sum adj cols: 0
# Error at: 68263
#       sum adj cols: 0
# Error at: 68264
#       sum adj cols: 0
# Error at: 68265
#       sum adj cols: 0
# Error at: 68266
#       sum adj cols: 0
# Error at: 68267
#       sum adj cols: 0
# Error at: 68359
#       sum adj cols: 0
# Error at: 68360
#       sum adj cols: 0
# Error at: 68361
#       sum adj cols: 0
# Error at: 68362
#       sum adj cols: 0
# Error at: 68363
#       sum adj cols: 0
# Error at: 68364
#       sum adj cols: 0
# Error at: 70768
#       sum adj cols: 0
# Error at: 70769
#       sum adj cols: 0
# Error at: 70770
#       sum adj cols: 0
# Error at: 70771
#       sum adj cols: 0
# Error at: 70772
#       sum adj cols: 0
# Error at: 70773
#       sum adj cols: 0
# Error at: 70776
#       sum adj cols: 0
# Error at: 70831
#       sum adj cols: 0
# Error at: 70963
#       sum adj cols: 0
# Error at: 70975
#       sum adj cols: 0
# Error at: 71107
#       sum adj cols: 0
# Error at: 71108
#       sum adj cols: 0
# Error at: 71109
#       sum adj cols: 0
# Error at: 71968
#       sum adj cols: 0
# Error at: 72929
#       sum adj cols: 0
# Error at: 72930
#       sum adj cols: 0
# Error at: 72931
#       sum adj cols: 0
# Error at: 72952
#       sum adj cols: 0
# Error at: 72953
#       sum adj cols: 0
# Error at: 72954
#       sum adj cols: 0
# Error at: 72955
#       sum adj cols: 0
# Error at: 72956
#       sum adj cols: 0
# Error at: 72957
#       sum adj cols: 0
# Error at: 72958
#       sum adj cols: 0
# Error at: 72960
#       sum adj cols: 0
# Error at: 72964
#       sum adj cols: 0
# Error at: 72965
#       sum adj cols: 0
# Error at: 72966
#       sum adj cols: 0
# Error at: 72967
#       sum adj cols: 0
# Error at: 72968
#       sum adj cols: 0
# Error at: 72969
#       sum adj cols: 0
# Error at: 72970
#       sum adj cols: 0
# Error at: 72971
#       sum adj cols: 0
# Error at: 72972
#       sum adj cols: 0
# Error at: 72973
#       sum adj cols: 0
# Error at: 73035
#       sum adj cols: 0
# Error at: 73036
#       sum adj cols: 0
# Error at: 73037
#       sum adj cols: 0
# Error at: 73389
#       sum adj cols: 0
# Error at: 73390
#       sum adj cols: 0
# Error at: 73391
#       sum adj cols: 0
# Error at: 73392
#       sum adj cols: 0
# Error at: 73393
#       sum adj cols: 0
# Error at: 73394
#       sum adj cols: 0
# Error at: 73395
#       sum adj cols: 0
# Error at: 73396
#       sum adj cols: 0
# Error at: 73397
#       sum adj cols: 0
# Error at: 73613
#       sum adj cols: 0
# Error at: 73614
#       sum adj cols: 0
# Error at: 73615
#       sum adj cols: 0
# Error at: 73616
#       sum adj cols: 0
# Error at: 73617
#       sum adj cols: 0
# Error at: 73757
#       sum adj cols: 0
# Error at: 73758
#       sum adj cols: 0
# Error at: 73759
#       sum adj cols: 0
# Error at: 73760
#       sum adj cols: 0
# Error at: 73761
#       sum adj cols: 0
# Error at: 73762
#       sum adj cols: 0
# Error at: 73984
#       sum adj cols: 0
# Error at: 76370
#       sum adj cols: 0
# Error at: 76382
#       sum adj cols: 0
# Error at: 76383
#       sum adj cols: 0
# Error at: 76384
#       sum adj cols: 0
# Error at: 76385
#       sum adj cols: 0
# Error at: 76386
#       sum adj cols: 0
# Error at: 76387
#       sum adj cols: 0
# Error at: 76388
#       sum adj cols: 0
# Error at: 76406
#       sum adj cols: 0
# Error at: 76407
#       sum adj cols: 0
# Error at: 76408
#       sum adj cols: 0
# Error at: 76409
#       sum adj cols: 0
# Error at: 76412
#       sum adj cols: 0
# Error at: 76414
#       sum adj cols: 0
# Error at: 76442
#       sum adj cols: 0
# Error at: 76443
#       sum adj cols: 0
# Error at: 76444
#       sum adj cols: 0
# Error at: 76445
#       sum adj cols: 0
# Error at: 76460
#       sum adj cols: 0
# Error at: 76462
#       sum adj cols: 0
# Error at: 76463
#       sum adj cols: 0
# Error at: 76753
#       sum adj cols: 0
# Error at: 76754
#       sum adj cols: 0
# Error at: 76755
#       sum adj cols: 0
# Error at: 76756
#       sum adj cols: 0
# Error at: 76757
#       sum adj cols: 0
# Error at: 76758
#       sum adj cols: 0
# Error at: 76759
#       sum adj cols: 0
# Error at: 76760
#       sum adj cols: 0
# Error at: 76761
#       sum adj cols: 0
# Error at: 76762
#       sum adj cols: 0
# Error at: 76763
#       sum adj cols: 0
# Error at: 76764
#       sum adj cols: 0
# Error at: 76765
#       sum adj cols: 0
# Error at: 76766
#       sum adj cols: 0
# Error at: 76767
#       sum adj cols: 0
# Error at: 76768
#       sum adj cols: 0
# Error at: 76769
#       sum adj cols: 0
# Error at: 78138
#       sum adj cols: 0
# Error at: 78291
#       sum adj cols: 0
# Error at: 78292
#       sum adj cols: 0
# Error at: 78293
#       sum adj cols: 0
# Error at: 78296
#       sum adj cols: 0
# Error at: 78297
#       sum adj cols: 0
# Error at: 78299
#       sum adj cols: 0
# Error at: 78300
#       sum adj cols: 0
# Error at: 78301
#       sum adj cols: 0
# Error at: 78302
#       sum adj cols: 0
# Error at: 78303
#       sum adj cols: 0
# Error at: 78305
#       sum adj cols: 0
# Error at: 78614
#       sum adj cols: 0
# Error at: 78615
#       sum adj cols: 0
# Error at: 78616
#       sum adj cols: 0
# Error at: 78617
#       sum adj cols: 0
# Error at: 78618
#       sum adj cols: 0
# Error at: 78619
#       sum adj cols: 0
# Error at: 78620
#       sum adj cols: 0
# Error at: 79532
#       sum adj cols: 0
# Error at: 79533
#       sum adj cols: 0
# Error at: 79534
#       sum adj cols: 0
# Error at: 79535
#       sum adj cols: 0
# Error at: 79536
#       sum adj cols: 0
# Error at: 79537
#       sum adj cols: 0
# Error at: 79538
#       sum adj cols: 0
# Error at: 79539
#       sum adj cols: 0
# Error at: 79540
#       sum adj cols: 0
# Error at: 79541
#       sum adj cols: 0
# Error at: 79542
#       sum adj cols: 0
# Error at: 79543
#       sum adj cols: 0
# Error at: 79876
#       sum adj cols: 0
# Error at: 79877
#       sum adj cols: 0
# Error at: 79878
#       sum adj cols: 0
# Error at: 79879
#       sum adj cols: 0
# Error at: 80014
#       sum adj cols: 0
# Error at: 80015
#       sum adj cols: 0
# Error at: 80016
#       sum adj cols: 0
# Error at: 80017
#       sum adj cols: 0
# Error at: 80055
#       sum adj cols: 0
# Error at: 80056
#       sum adj cols: 0
# Error at: 80057
#       sum adj cols: 0
# Error at: 80058
#       sum adj cols: 0
# Error at: 80059
#       sum adj cols: 0
# Error at: 80060
#       sum adj cols: 0
# Error at: 80061
#       sum adj cols: 0
# Error at: 80482
#       sum adj cols: 0
# Error at: 80483
#       sum adj cols: 0
# Error at: 80484
#       sum adj cols: 0
# Error at: 80485
#       sum adj cols: 0
# Error at: 80486
#       sum adj cols: 0
# Error at: 80549
#       sum adj cols: 0
# Error at: 80550
#       sum adj cols: 0
# Error at: 80551
#       sum adj cols: 0
# Error at: 80552
#       sum adj cols: 0
# Error at: 80553
#       sum adj cols: 0
# Error at: 80555
#       sum adj cols: 0
# Error at: 80556
#       sum adj cols: 0
# Error at: 80557
#       sum adj cols: 0
# Error at: 80558
#       sum adj cols: 0
# Error at: 80589
#       sum adj cols: 0
# Error at: 80600
#       sum adj cols: 0
# Error at: 80601
#       sum adj cols: 0
# Error at: 84840
#       sum adj cols: 0
# Error at: 84842
#       sum adj cols: 0
# Error at: 84869
#       sum adj cols: 0
# Error at: 85458
#       sum adj cols: 0
# Error at: 85459
#       sum adj cols: 0
# Error at: 85791
#       sum adj cols: 0
# Error at: 86236
#       sum adj cols: 0
# Error at: 86237
#       sum adj cols: 0
# Error at: 86239
#       sum adj cols: 0
# Error at: 87019
#       sum adj cols: 0
# Error at: 87455
#       sum adj cols: 0
# Error at: 87456
#       sum adj cols: 0
# Error at: 87483
#       sum adj cols: 0
# Error at: 87795
#       sum adj cols: 0
# Error at: 87800
#       sum adj cols: 0
# Error at: 87801
#       sum adj cols: 0
# Error at: 87802
#       sum adj cols: 0
# Error at: 87803
#       sum adj cols: 0
# Error at: 88109
#       sum adj cols: 0
# Error at: 88110
#       sum adj cols: 0
# Error at: 88111
#       sum adj cols: 0
# Error at: 88112
#       sum adj cols: 0
# Error at: 88113
#       sum adj cols: 0
# Error at: 88120
#       sum adj cols: 0
# Error at: 88123
#       sum adj cols: 0
# Error at: 88124
#       sum adj cols: 0
# Error at: 88125
#       sum adj cols: 0
# Error at: 88578
#       sum adj cols: 0
# Error at: 89851
#       sum adj cols: 0
# Error at: 90880
#       sum adj cols: 0
# Error at: 91867
#       sum adj cols: 0
# Error at: 91868
#       sum adj cols: 0
# Error at: 91897
#       sum adj cols: 0
# Error at: 91898
#       sum adj cols: 0
# Error at: 91899
#       sum adj cols: 0
# Error at: 91901
#       sum adj cols: 0
# Error at: 91902
#       sum adj cols: 0
# Error at: 91903
#       sum adj cols: 0
# Error at: 91904
#       sum adj cols: 0
# Error at: 91910
#       sum adj cols: 0
# Error at: 91911
#       sum adj cols: 0
# Error at: 91912
#       sum adj cols: 0
# Error at: 91913
#       sum adj cols: 0
# Error at: 91914
#       sum adj cols: 0
# Error at: 91915
#       sum adj cols: 0
# Error at: 91917
#       sum adj cols: 0
# Error at: 91921
# ...
# Error at: 598012
#       sum adj cols: 0
# Error at: 598013
#       sum adj cols: 0
# Error at: 598015
#       sum adj cols: 0
# Error at: 598016
#       sum adj cols: 0
# Error at: 598017
#       sum adj cols: 0
# Error at: 598018
#       sum adj cols: 0
# Error at: 598019
#       sum adj cols: 0
# Error at: 598020
#       sum adj cols: 0
# Error at: 598021
#       sum adj cols: 0
# Error at: 598022
#       sum adj cols: 0
# Error at: 598023
#       sum adj cols: 0
# Error at: 598294
#       sum adj cols: 0
# Error at: 598295
#       sum adj cols: 0
# Error at: 598296
#       sum adj cols: 0
# Error at: 598297
#       sum adj cols: 0
# Error at: 598298
#       sum adj cols: 0
# Error at: 598299
#       sum adj cols: 0
# Error at: 598300
#       sum adj cols: 0
# Error at: 598301
#       sum adj cols: 0
# Error at: 598510
#       sum adj cols: 0
# Error at: 598693
#       sum adj cols: 0
# Error at: 598705
#       sum adj cols: 0
# Error at: 598717
#       sum adj cols: 0
# Error at: 598729
#       sum adj cols: 0
# Error at: 598813
#       sum adj cols: 0
# Error at: 598825
#       sum adj cols: 0
# Error at: 598826
#       sum adj cols: 0
# Error at: 598827
#       sum adj cols: 0
# Error at: 598828
#       sum adj cols: 0
# Error at: 598829
#       sum adj cols: 0
# Error at: 598830
#       sum adj cols: 0
# Error at: 598831
#       sum adj cols: 0
# Error at: 598832
#       sum adj cols: 0
# Error at: 598833
#       sum adj cols: 0
# Error at: 598834
#       sum adj cols: 0
# Error at: 598835
#       sum adj cols: 0
# Error at: 598836
#       sum adj cols: 0
# Error at: 598837
#       sum adj cols: 0
# Error at: 598838
#       sum adj cols: 0
# Error at: 598839
#       sum adj cols: 0
# Error at: 598840
#       sum adj cols: 0
# Error at: 598841
#       sum adj cols: 0
# Error at: 598842
#       sum adj cols: 0
# Error at: 598843
#       sum adj cols: 0
# Error at: 598844
#       sum adj cols: 0
# Error at: 598845
#       sum adj cols: 0
# Error at: 598846
#       sum adj cols: 0
# Error at: 598847
#       sum adj cols: 0
# Error at: 598848
#       sum adj cols: 0
# Error at: 598849
#       sum adj cols: 0
# Error at: 598850
#       sum adj cols: 0
# Error at: 598851
#       sum adj cols: 0
# Error at: 598852
#       sum adj cols: 0
# Error at: 598853
#       sum adj cols: 0
# Error at: 598854
#       sum adj cols: 0
# Error at: 598855
#       sum adj cols: 0
# Error at: 598856
#       sum adj cols: 0
# Error at: 598857
#       sum adj cols: 0
# Error at: 598858
#       sum adj cols: 0
# Error at: 598859
#       sum adj cols: 0
# Error at: 598860
#       sum adj cols: 0
# Error at: 598861
#       sum adj cols: 0
# Error at: 598862
#       sum adj cols: 0
# Error at: 598863
#       sum adj cols: 0
# Error at: 598864
#       sum adj cols: 0
# Error at: 598865
#       sum adj cols: 0
# Error at: 598866
#       sum adj cols: 0
# Error at: 598867
#       sum adj cols: 0
# Error at: 598868
#       sum adj cols: 0
# Error at: 598869
#       sum adj cols: 0
# Error at: 598870
#       sum adj cols: 0
# Error at: 598871
#       sum adj cols: 0
# Error at: 598872
#       sum adj cols: 0
# Error at: 598873
#       sum adj cols: 0
# Error at: 598874
#       sum adj cols: 0
# Error at: 598875
#       sum adj cols: 0
# Error at: 598876
#       sum adj cols: 0
# Error at: 598877
#       sum adj cols: 0
# Error at: 598878
#       sum adj cols: 0
# Error at: 598879
#       sum adj cols: 0
# Error at: 598880
#       sum adj cols: 0
# Error at: 598881
#       sum adj cols: 0
# Error at: 598882
#       sum adj cols: 0
# Error at: 598883
#       sum adj cols: 0
# Error at: 598884
#       sum adj cols: 0
# Error at: 598885
#       sum adj cols: 0
# Error at: 598886
#       sum adj cols: 0
# Error at: 598887
#       sum adj cols: 0
# Error at: 598888
#       sum adj cols: 0
# Error at: 598889
#       sum adj cols: 0
# Error at: 598890
#       sum adj cols: 0
# Error at: 598969
#       sum adj cols: 0
# Error at: 599005
#       sum adj cols: 0
# Error at: 599017
#       sum adj cols: 0
# Error at: 599029
#       sum adj cols: 0
# Error at: 599101
#       sum adj cols: 0
# Error at: 599137
#       sum adj cols: 0
# Error at: 599149
#       sum adj cols: 0
# Error at: 599161
#       sum adj cols: 0
# Error at: 599173
#       sum adj cols: 0
# Error at: 599185
#       sum adj cols: 0
# Error at: 599257
#       sum adj cols: 0
# Error at: 599269
#       sum adj cols: 0
# Error at: 599281
#       sum adj cols: 0
# Error at: 599317
#       sum adj cols: 0
# Error at: 599318
#       sum adj cols: 0
# Error at: 599319
#       sum adj cols: 0
# Error at: 599320
#       sum adj cols: 0
# Error at: 599331
#       sum adj cols: 0
# Error at: 599343
#       sum adj cols: 0
# Error at: 599355
#       sum adj cols: 0
# Error at: 599439
#       sum adj cols: 0
# Error at: 599451
#       sum adj cols: 0
# Error at: 599463
#       sum adj cols: 0
# Error at: 599547
#       sum adj cols: 0
# Error at: 599559
#       sum adj cols: 0
# Error at: 599634
#       sum adj cols: 0
# Error at: 599635
#       sum adj cols: 0
# Error at: 599636
#       sum adj cols: 0
# Error at: 599637
#       sum adj cols: 0
# Error at: 599638
#       sum adj cols: 0
# Error at: 599639
#       sum adj cols: 0
# Error at: 599715
#       sum adj cols: 0
# Error at: 599859
#       sum adj cols: 0
# Error at: 599871
#       sum adj cols: 0
# Error at: 600003
#       sum adj cols: 0
# Error at: 600471
#       sum adj cols: 0
# Error at: 600483
#       sum adj cols: 0
# Error at: 600495
#       sum adj cols: 0
# Error at: 600735
#       sum adj cols: 0
# Error at: 600771
#       sum adj cols: 0
# Error at: 600915
#       sum adj cols: 0
# Error at: 600937
#       sum adj cols: 0
# Error at: 600949
#       sum adj cols: 0
# Error at: 600972
#       sum adj cols: 0
# Error at: 600973
#       sum adj cols: 0
# Error at: 600974
#       sum adj cols: 0
# Error at: 600975
#       sum adj cols: 0
# Error at: 600976
#       sum adj cols: 0
# Error at: 600977
#       sum adj cols: 0
# Error at: 600978
#       sum adj cols: 0
# Error at: 600979
#       sum adj cols: 0
# Error at: 600980
#       sum adj cols: 0
# Error at: 600981
#       sum adj cols: 0
# Error at: 600982
#       sum adj cols: 0
# Error at: 600983
#       sum adj cols: 0
# Error at: 600997
#       sum adj cols: 0
# Error at: 601021
#       sum adj cols: 0
# Error at: 601039
#       sum adj cols: 0
# Error at: 601040
#       sum adj cols: 0
# Error at: 601041
#       sum adj cols: 0
# Error at: 601042
#       sum adj cols: 0
# Error at: 601043
#       sum adj cols: 0
# Error at: 601044
#       sum adj cols: 0
# Error at: 601045
#       sum adj cols: 0
# Error at: 601046
#       sum adj cols: 0
# Error at: 601047
#       sum adj cols: 0
# Error at: 601048
#       sum adj cols: 0
# Error at: 601049
#       sum adj cols: 0
# Error at: 601050
#       sum adj cols: 0
# Error at: 601057
#       sum adj cols: 0
# Error at: 601069
#       sum adj cols: 0
# Error at: 601081
#       sum adj cols: 0
# Error at: 601105
#       sum adj cols: 0
# Error at: 601117
#       sum adj cols: 0
# Error at: 601129
#       sum adj cols: 0
# Error at: 601141
#       sum adj cols: 0
# Error at: 601165
#       sum adj cols: 0
# Error at: 601201
#       sum adj cols: 0
# Error at: 601237
#       sum adj cols: 0
# Error at: 601321
#       sum adj cols: 0
# Error at: 601333
#       sum adj cols: 0
# Error at: 601345
#       sum adj cols: 0
# Error at: 601357
#       sum adj cols: 0
# Error at: 601369
#       sum adj cols: 0
# Error at: 601393
#       sum adj cols: 0
# Error at: 601477
#       sum adj cols: 0
# Error at: 601489
#       sum adj cols: 0
# Error at: 601501
#       sum adj cols: 0
# Error at: 601513
#       sum adj cols: 0
# Error at: 601525
#       sum adj cols: 0
# Error at: 601621
#       sum adj cols: 0
# Error at: 601633
#       sum adj cols: 0
# Error at: 601645
#       sum adj cols: 0
# Error at: 601693
#       sum adj cols: 0
# Error at: 602911
#       sum adj cols: 0
# Error at: 602912
#       sum adj cols: 0
# Error at: 602913
#       sum adj cols: 0
# Error at: 602914
#       sum adj cols: 0
# Error at: 602915
#       sum adj cols: 0
# Error at: 602916
#       sum adj cols: 0
# Error at: 602917
#       sum adj cols: 0
# Error at: 602968
#       sum adj cols: 0
# Error at: 602969
#       sum adj cols: 0
# Error at: 602970
#       sum adj cols: 0
# Error at: 602971
#       sum adj cols: 0
# Error at: 603045
#       sum adj cols: 0
# Error at: 603046
#       sum adj cols: 0
# Error at: 603047
#       sum adj cols: 0
# Error at: 603048
#       sum adj cols: 0
# Error at: 603049
#       sum adj cols: 0
# Error at: 603361
#       sum adj cols: 0
# Error at: 604089
#       sum adj cols: 0
# Error at: 604090
#       sum adj cols: 0
# Error at: 604091
#       sum adj cols: 0
# Error at: 604092
#       sum adj cols: 0
# Error at: 604095
#       sum adj cols: 0
# Error at: 604096
#       sum adj cols: 0
# Error at: 604097
#       sum adj cols: 0
# Error at: 605262
#       sum adj cols: 0
# Error at: 605272
#       sum adj cols: 0
# Error at: 605280
#       sum adj cols: 0
# Error at: 605281
#       sum adj cols: 0
# Error at: 605282
#       sum adj cols: 0
# Error at: 605284
#       sum adj cols: 0
# Error at: 605285
#       sum adj cols: 0
# Error at: 605286
#       sum adj cols: 0
# Error at: 605293
#       sum adj cols: 0
# Error at: 605294
#       sum adj cols: 0
# Error at: 605295
#       sum adj cols: 0
# Error at: 605296
#       sum adj cols: 0
# Error at: 605297
#       sum adj cols: 0
# Error at: 605298
#       sum adj cols: 0
# Error at: 605301
#       sum adj cols: 0
# Error at: 605303
#       sum adj cols: 0
# Error at: 605307
#       sum adj cols: 0
# Error at: 605308
#       sum adj cols: 0
# Error at: 605313
#       sum adj cols: 0
# Error at: 605314
#       sum adj cols: 0
# Error at: 605319
#       sum adj cols: 0
# Error at: 605320
#       sum adj cols: 0
# Error at: 605321
#       sum adj cols: 0
# Error at: 605322
#       sum adj cols: 0
# Error at: 605325
#       sum adj cols: 0
# Error at: 605326
#       sum adj cols: 0
# Error at: 605327
#       sum adj cols: 0
# Error at: 605328
#       sum adj cols: 0
# Error at: 605329
#       sum adj cols: 0
# Error at: 605330
#       sum adj cols: 0
# Error at: 605331
#       sum adj cols: 0
# Error at: 605332
#       sum adj cols: 0
# Error at: 605333
#       sum adj cols: 0
# Error at: 605334
#       sum adj cols: 0
# Error at: 605335
#       sum adj cols: 0
# Error at: 605336
#       sum adj cols: 0
# Error at: 605337
#       sum adj cols: 0
# Error at: 605339
#       sum adj cols: 0
# Error at: 605340
#       sum adj cols: 0
# Error at: 605343
#       sum adj cols: 0
# Error at: 605344
#       sum adj cols: 0
# Error at: 605345
#       sum adj cols: 0
# Error at: 605346
#       sum adj cols: 0
# Error at: 605352
#       sum adj cols: 0
# Error at: 605464
#       sum adj cols: 0
# Error at: 605465
#       sum adj cols: 0
# Error at: 605466
#       sum adj cols: 0
# Error at: 605467
#       sum adj cols: 0
# Error at: 605468
#       sum adj cols: 0
# Error at: 605469
#       sum adj cols: 0
# Error at: 605470
#       sum adj cols: 0
# Error at: 605471
#       sum adj cols: 0
# Error at: 605472
#       sum adj cols: 0
# Error at: 605473
#       sum adj cols: 0
# Error at: 605811
#       sum adj cols: 0
# Error at: 605812
#       sum adj cols: 0
# Error at: 606050
#       sum adj cols: 0
# Error at: 606051
#       sum adj cols: 0
# Error at: 606883
#       sum adj cols: 0
# Error at: 606884
#       sum adj cols: 0
# Error at: 606885
#       sum adj cols: 0
# Error at: 606886
#       sum adj cols: 0
# Error at: 607561
#       sum adj cols: 0
# Error at: 607562
#       sum adj cols: 0
# Error at: 607563
#       sum adj cols: 0
# Error at: 607564
#       sum adj cols: 0
# Error at: 607565
#       sum adj cols: 0
# Error at: 607566
#       sum adj cols: 0
# Error at: 607567
#       sum adj cols: 0
# Error at: 607568
#       sum adj cols: 0
# Error at: 607569
#       sum adj cols: 0
# Error at: 607570
#       sum adj cols: 0
# Error at: 607571
#       sum adj cols: 0
# Error at: 607612
#       sum adj cols: 0
# Error at: 607633
#       sum adj cols: 0
# Error at: 607634
#       sum adj cols: 0
# Error at: 607635
#       sum adj cols: 0
# Error at: 607636
#       sum adj cols: 0
# Error at: 607685
#       sum adj cols: 0
# Error at: 607686
#       sum adj cols: 0
# Error at: 607687
#       sum adj cols: 0
# Error at: 607688
#       sum adj cols: 0
# Error at: 607689
#       sum adj cols: 0
# Error at: 607690
#       sum adj cols: 0
# Error at: 607691
#       sum adj cols: 0
# Error at: 608770
#       sum adj cols: 0
# Error at: 609145
#       sum adj cols: 0
# Error at: 609699
#       sum adj cols: 0
# Error at: 609709
#       sum adj cols: 0
# Error at: 609710
#       sum adj cols: 0
# Error at: 609711
#       sum adj cols: 0
# Error at: 609712
#       sum adj cols: 0
# Error at: 609713
#       sum adj cols: 0
# Error at: 609714
#       sum adj cols: 0
# Error at: 609717
#       sum adj cols: 0
# Error at: 609719
#       sum adj cols: 0
# Error at: 609720
#       sum adj cols: 0
# Error at: 609733
#       sum adj cols: 0
# Error at: 609734
#       sum adj cols: 0
# Error at: 609736
#       sum adj cols: 0
# Error at: 609748
#       sum adj cols: 0
# Error at: 609750
#       sum adj cols: 0
# Error at: 609754
#       sum adj cols: 0
# Error at: 609759
#       sum adj cols: 0
# Error at: 609760
#       sum adj cols: 0
# Error at: 609761
#       sum adj cols: 0
# Error at: 609762
#       sum adj cols: 0
# Error at: 609765
#       sum adj cols: 0
# Error at: 609767
#       sum adj cols: 0
# Error at: 609768
#       sum adj cols: 0
# Error at: 609777
#       sum adj cols: 0
# Error at: 609779
#       sum adj cols: 0
# Error at: 609780
#       sum adj cols: 0
# Error at: 609783
#       sum adj cols: 0
# Error at: 609784
#       sum adj cols: 0
# Error at: 609785
#       sum adj cols: 0
# Error at: 609786
#       sum adj cols: 0
# Error at: 609789
#       sum adj cols: 0
# Error at: 610738
#       sum adj cols: 0
# Error at: 610739
#       sum adj cols: 0
# Error at: 610740
#       sum adj cols: 0
# Error at: 610741
#       sum adj cols: 0
# Error at: 610742
#       sum adj cols: 0
# Error at: 610743
#       sum adj cols: 0
# Error at: 610744
#       sum adj cols: 0
# Error at: 610745
#       sum adj cols: 0
# Error at: 610746
#       sum adj cols: 0
# Error at: 610747
#       sum adj cols: 0
# Error at: 610748
#       sum adj cols: 0
# Error at: 610749
#       sum adj cols: 0
# Error at: 610750
#       sum adj cols: 0
# Error at: 610751
#       sum adj cols: 0
# Error at: 610752
#       sum adj cols: 0
# Error at: 610753
#       sum adj cols: 0
# Error at: 611025
#       sum adj cols: 0
# Error at: 611026
#       sum adj cols: 0
# Error at: 611027
#       sum adj cols: 0
# Error at: 611249
#       sum adj cols: 0
# Error at: 611250
#       sum adj cols: 0
# Error at: 611251
#       sum adj cols: 0
# Error at: 611252
#       sum adj cols: 0
# Error at: 611253
#       sum adj cols: 0
# Error at: 611254
#       sum adj cols: 0
# Error at: 611255
#       sum adj cols: 0
# Error at: 611256
#       sum adj cols: 0
# Error at: 611257
#       sum adj cols: 0
# Error at: 611258
#       sum adj cols: 0
# Error at: 611259
#       sum adj cols: 0
# Error at: 611260
#       sum adj cols: 0
# Error at: 611261
#       sum adj cols: 0
# Error at: 611262
#       sum adj cols: 0
# Error at: 611263
#       sum adj cols: 0
# Error at: 611264
#       sum adj cols: 0
# Error at: 611265
#       sum adj cols: 0
# Error at: 611266
#       sum adj cols: 0
# Error at: 611267
#       sum adj cols: 0
# Error at: 611268
#       sum adj cols: 0
# Error at: 611269
#       sum adj cols: 0
# Error at: 611270
#       sum adj cols: 0
# Error at: 611351
#       sum adj cols: 0
# Error at: 611352
#       sum adj cols: 0
# Error at: 611353
#       sum adj cols: 0
# Error at: 611354
#       sum adj cols: 0
# Error at: 611355
#       sum adj cols: 0
# Error at: 611793
#       sum adj cols: 0
# Error at: 612571
#       sum adj cols: 0
# Error at: 612572
#       sum adj cols: 0
# Error at: 612573
#       sum adj cols: 0
# Error at: 612574
#       sum adj cols: 0
# Error at: 612575
#       sum adj cols: 0
# Error at: 612576
#       sum adj cols: 0
# Error at: 612694
#       sum adj cols: 0
# Error at: 612703
#       sum adj cols: 0
# Error at: 612704
#       sum adj cols: 0
# Error at: 612705
#       sum adj cols: 0
# Error at: 612706
#       sum adj cols: 0
# Error at: 612707
#       sum adj cols: 0
# Error at: 613691
#       sum adj cols: 0
# Error at: 613692
#       sum adj cols: 0
# Error at: 613693
#       sum adj cols: 0
# Error at: 613694
#       sum adj cols: 0
# Error at: 613695
#       sum adj cols: 0
# Error at: 613696
#       sum adj cols: 0
# Error at: 613850
#       sum adj cols: 0
# Error at: 615297
#       sum adj cols: 0
# Error at: 615490
#       sum adj cols: 0
# Error at: 615491
#       sum adj cols: 0
# Error at: 615492
#       sum adj cols: 0
# Error at: 615493
#       sum adj cols: 0
# Error at: 616972
#       sum adj cols: 0
# Error at: 616973
#       sum adj cols: 0
# Error at: 616974
#       sum adj cols: 0
# Error at: 618098
#       sum adj cols: 0
# Error at: 618099
#       sum adj cols: 0
# Error at: 618100
#       sum adj cols: 0
# Error at: 618128
#       sum adj cols: 0
# Error at: 618563
#       sum adj cols: 0
# Error at: 618564
#       sum adj cols: 0
# Error at: 618565
#       sum adj cols: 0
# Error at: 618566
#       sum adj cols: 0
# Error at: 618567
#       sum adj cols: 0

# %%
# I bet you NASAs first launch was a failure too
row_indexes[0]
# Out:
# 1195

# %%
# My hypothesis is that these rows are missing too much information to calculate their punctuality.
wego_trim.iloc[row_indexes[0]:row_indexes[0]+1]
# Out:
#          cal_id  service_day        date  operator_id  trip_id  \
# 1195  120230103            1  2023-01-03          664   332455
#
#      route_direction time_point  trip_edge sched_time ACTUAL_ARRIVAL_TIME  \
# 1195   FROM DOWNTOWN   28&CHARL          0   11:40:00                 NaN
#
#       ... sched_hdwy  act_hdwy  hdwy_dev  adj_early  adj_late  adj_ontime  \
# 1195  ...       15.0       NaN       NaN          0         0           0
#
#       STOP_CANCELLED  PREV_SCHED_STOP_CANCELLED  IS_RELIEF  timing_flag
# 1195               0                        0.0          0          NaN
#
# [1 rows x 22 columns]

# %%
# Hypothesis correct
wego_trim.iloc[row_indexes[0]:row_indexes[0]+1][['sched_time', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME']]
# Out:
#      sched_time ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME
# 1195   11:40:00                 NaN                   NaT

# %%
# Now the plan is to use the indexes I saved to remove dirty rows.
len(row_indexes)
# Out:
# 18218

# %%
# Check original size
wego_trim.shape
# Out:
# (618998, 22)

# %%
# This is the number we should get
print(wego_trim.shape[0] - len(row_indexes))
# Out:
# 600780

# %%
# Drop dirty rows
wego_trim = wego_trim.drop(row_indexes)

# %%
# Check new size
wego_trim.shape
# Out:
# (600780, 22)

# %%
wego_trim.head(1)
# Out:
#       cal_id  service_day        date  operator_id  trip_id route_direction  \
# 0  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
#
#   time_point  trip_edge sched_time ACTUAL_ARRIVAL_TIME  ... sched_hdwy  \
# 0       WALM          1   05:34:00            05:29:52  ...        NaN
#
#    act_hdwy  hdwy_dev  adj_early  adj_late  adj_ontime  STOP_CANCELLED  \
# 0       NaN       NaN          0         0           1               0
#
#    PREV_SCHED_STOP_CANCELLED  IS_RELIEF  timing_flag
# 0                        0.0          0          3.0
#
# [1 rows x 22 columns]

# %%
# It's a float why
wego_trim['timing_flag'] = wego_trim['timing_flag'].astype(int)

# %%
# Removing the 3 adj_ columns, now all we need is 'timing_flag'
wego_trim = wego_trim.drop(columns=['adj_early', 'adj_late', 'adj_ontime'])

# %%
# Squeaky clean
wego_trim.head()
# Out:
#       cal_id  service_day        date  operator_id  trip_id route_direction  \
# 0  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 1  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 2  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 3  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 4  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
#
#   time_point  trip_edge sched_time ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  \
# 0       WALM          1   05:34:00            05:29:52              05:38:00
# 1       HLWD          0   05:40:00            05:42:38              05:42:38
# 2       WHBG          0   05:47:00            05:48:29              05:48:29
# 3       CH46          0   05:50:00            05:50:34              05:50:34
# 4   28&CHARL          0   05:54:00            05:53:14              05:55:23
#
#    adherence  sched_hdwy  act_hdwy  hdwy_dev  STOP_CANCELLED  \
# 0  -4.000000         NaN       NaN       NaN               0
# 1  -2.633333         NaN       NaN       NaN               0
# 2  -1.483333         NaN       NaN       NaN               0
# 3  -0.566666         NaN       NaN       NaN               0
# 4  -1.383333         NaN       NaN       NaN               0
#
#    PREV_SCHED_STOP_CANCELLED  IS_RELIEF  timing_flag
# 0                        0.0          0            3
# 1                        0.0          0            3
# 2                        0.0          0            3
# 3                        0.0          0            3
# 4                        0.0          0            3

# %% [markdown]
# ### Filtering out NaNs

# %%
# I love that there is so much missing data in the headway department
wego_trim.head()
# Out:
#       cal_id  service_day        date  operator_id  trip_id route_direction  \
# 0  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 1  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 2  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 3  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
# 4  120230101            3  2023-01-01         2355   332422     TO DOWNTOWN
#
#   time_point  trip_edge sched_time ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  \
# 0       WALM          1   05:34:00            05:29:52              05:38:00
# 1       HLWD          0   05:40:00            05:42:38              05:42:38
# 2       WHBG          0   05:47:00            05:48:29              05:48:29
# 3       CH46          0   05:50:00            05:50:34              05:50:34
# 4   28&CHARL          0   05:54:00            05:53:14              05:55:23
#
#    adherence  sched_hdwy  act_hdwy  hdwy_dev  STOP_CANCELLED  \
# 0  -4.000000         NaN       NaN       NaN               0
# 1  -2.633333         NaN       NaN       NaN               0
# 2  -1.483333         NaN       NaN       NaN               0
# 3  -0.566666         NaN       NaN       NaN               0
# 4  -1.383333         NaN       NaN       NaN               0
#
#    PREV_SCHED_STOP_CANCELLED  IS_RELIEF tsp_status  timing_flag
# 0                        0.0          0    tsp_off            3
# 1                        0.0          0    tsp_off            3
# 2                        0.0          0    tsp_off            3
# 3                        0.0          0    tsp_off            3
# 4                        0.0          0    tsp_off            3

# %%
# Viewing columns to select important metrics
wego_trim.columns
# Out:
# Index(['cal_id', 'service_day', 'date', 'operator_id', 'trip_id',
#        'route_direction', 'time_point', 'trip_edge', 'sched_time',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'adherence',
#        'sched_hdwy', 'act_hdwy', 'hdwy_dev', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'tsp_status', 'timing_flag'],
#       dtype='object')

# %%
# I guess this is it?
dirty_rows = wego_trim[wego_trim[['ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'adherence']].isna().any(axis=1)]
dirty_rows
# Out:
#            cal_id  service_day        date  operator_id  trip_id  \
# 217617  120231104            2  2023-11-04         2629   361579
# 244983  120231212            1  2023-12-12         1791   366776
# 315006  120240318            1  2024-03-18         2448   374570
# 338082  120240419            1  2024-04-19         2137   377471
# 452155  120240924            1  2024-09-24          664   394633
# 506322  120241207            2  2024-12-07         3388   406166
# 508794  120241211            1  2024-12-11         1457   406025
# 522509  120241230            1  2024-12-30         3124   412017
# 548103  120250204            1  2025-02-04         1623   417857
# 563932  120250226            1  2025-02-26         1893   423678
#
#        route_direction time_point  trip_edge sched_time ACTUAL_ARRIVAL_TIME  \
# 217617   FROM DOWNTOWN     MCC5_1          1   09:15:00                 NaN
# 244983   FROM DOWNTOWN       WALM          2   18:35:00                 NaN
# 315006     TO DOWNTOWN       MLKS          1   15:20:00                 NaN
# 338082   FROM DOWNTOWN     MCC5_1          1   07:00:00                 NaN
# 452155   FROM DOWNTOWN     MCC5_1          1   06:15:00                 NaN
# 506322   FROM DOWNTOWN     MCC5_1          1   15:15:00                 NaN
# 508794     TO DOWNTOWN   28&CHARL          0   12:24:00                 NaN
# 522509   FROM DOWNTOWN     MCC5_1          1   20:15:00                 NaN
# 548103     TO DOWNTOWN       WALM          1   19:32:00                 NaN
# 563932   FROM DOWNTOWN     MCC5_1          1   12:30:00                 NaN
#
#        ACTUAL_DEPARTURE_TIME   adherence  sched_hdwy    act_hdwy    hdwy_dev  \
# 217617              09:29:28  -14.466666        30.0   43.116666   13.116666
# 244983              18:45:32  -10.533333         NaN         NaN         NaN
# 315006              20:56:40 -336.666666        10.0  345.100000  335.100000
# 338082              07:03:18   -3.300000        15.0    0.533333  -14.466667
# 452155              06:15:20   -0.333333        35.0   32.733333   -2.266667
# 506322              15:38:10  -23.166666        20.0   38.366666   18.366666
# 508794              13:55:14  -91.233333        15.0   12.516666   -2.483334
# 522509              20:19:42   -4.700000        30.0   32.783333    2.783333
# 548103              20:17:04  -45.066666        31.0    3.900000  -27.100000
# 563932              15:44:38 -194.633333        15.0   11.033333   -3.966667
#
#         STOP_CANCELLED  PREV_SCHED_STOP_CANCELLED  IS_RELIEF  \
# 217617               1                        0.0          0
# 244983               0                        NaN          0
# 315006               0                        0.0          0
# 338082               1                        0.0          0
# 452155               0                        0.0          0
# 506322               0                        0.0          0
# 508794               0                        0.0          0
# 522509               0                        0.0          0
# 548103               0                        0.0          0
# 563932               0                        0.0          0
#
#               tsp_status  timing_flag
# 217617  tsp_on_hdwy_cond            2
# 244983  tsp_on_hdwy_cond            2
# 315006  tsp_on_hdwy_cond            2
# 338082  tsp_on_hdwy_cond            3
# 452155  tsp_on_hdwy_cond            3
# 506322  tsp_on_hdwy_cond            2
# 508794  tsp_on_hdwy_cond            2
# 522509  tsp_on_hdwy_cond            3
# 548103  tsp_on_hdwy_cond            2
# 563932  tsp_on_hdwy_cond            2

# %%
# Show the full trips associated with the dirty rows
dirty_df = (
    wego_trim
    .loc[wego_trim['cal_id'].isin(dirty_rows['cal_id'])]
    .loc[wego_trim['trip_id'].isin(dirty_rows['trip_id'])]
    .sort_values(['cal_id', 'trip_id'])
)

# %%
dirty_df.shape
# Out:
# (39, 20)

# %%
wego_trim.loc[wego_trim['tsp_status'] == 'tsp_on_hdwy_cond'].shape
# Out:
# (509314, 20)

# %%
def extract_indexes(df):
    return_list = []
    for x in df:
        return_list.append(x.name())
    return return_list

# %%
# Save indexes of dirty trips to list
dirty_indexes_1 = extract_indexes(wego_trim.loc[wego_trim['cal_id'].isin(dirty_rows['cal_id'])].loc[wego_trim['trip_id'].isin(dirty_rows['trip_id'])].sort_values(['cal_id', 'trip_id'])

# %%
# Remove dirty trips
wego_trim.drop
